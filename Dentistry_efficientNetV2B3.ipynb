# %% [markdown]
# # **Part - 1**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import tensorflow as tf
import tensorflow
from tensorflow.keras.preprocessing.image import load_img, ImageDataGenerator
import cv2
import time
import random
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Activation

# %%
# Path to Datasets
# Training Path
train_caries_path = "/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/training/caries"
train_no_caries_path = "/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/training/no-caries"

# Testing Path 
valid_caries_path = "/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/validation/caries"
valid_no_caries_path = "/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/validation/no-caries"

# Testing Path 
test_caries_path = "/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/test/caries"
test_no_caries_path = "/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/test/no-caries"

# %%
# Making Directory of Images
# Training Images
train_caries_image = os.listdir(train_caries_path)
train_no_caries_image = os.listdir(train_no_caries_path)

#Validation Images
valid_caries_image = os.listdir(valid_caries_path)
valid_no_caries_image = os.listdir(valid_no_caries_path)

#Testing Images
test_caries_image = os.listdir(test_caries_path)
test_no_caries_image = os.listdir(test_no_caries_path)

# %%
# Printing Numbers of Images in each Dataset
print("Number of Caries Images in Training = ",len(train_caries_image))
print("Number of No Caries Images in Training = ",len(train_no_caries_image))

print('\n')
print("Number of Caries Images in Validation = ",len(valid_caries_image))
print("Number of No Caries Images in Validation = ",len(valid_no_caries_image))

print('\n')
print("Number of Caries Images in Testing = ",len(test_caries_image))
print("Number of No Caries Images in Testing = ",len(test_no_caries_image))
# Out:
# Number of Caries Images in Training =  765
# Number of No Caries Images in Training =  315
#
#
# Number of Caries Images in Validation =  211
# Number of No Caries Images in Validation =  211
#
#
# Number of Caries Images in Testing =  210
# Number of No Caries Images in Testing =  82

# %% [markdown]
# # **Part - 2**

# %% [markdown]
# Training Data

# %%
m=0
fig, axes = plt.subplots(2,3, figsize=(10,10))
axes = axes.ravel()

for i in range(3):
  img = plt.imread(train_caries_path + '/' + random.choice(train_caries_image))
  axes[m].imshow(img)
  axes[m].set_title("Caries")
  m=m+1

for i in range(3):
  img = plt.imread(train_no_caries_path + '/' + random.choice(train_no_caries_image))
  axes[m].imshow(img)
  axes[m].set_title("No - Caries")
  m=m+1

# %% [markdown]
# Validation Data

# %%
m=0
fig, axes = plt.subplots(2,3, figsize=(10,10))
axes = axes.ravel()

for i in range(3):
  img = plt.imread(valid_caries_path + '/' + random.choice(valid_caries_image))
  axes[m].imshow(img)
  axes[m].set_title("Caries")
  m=m+1

for i in range(3):
  img = plt.imread(valid_no_caries_path + '/' + random.choice(valid_no_caries_image))
  axes[m].imshow(img)
  axes[m].set_title("No - Caries")
  m=m+1

# %% [markdown]
# Test Data

# %%
m=0
fig, axes = plt.subplots(2,3, figsize=(10,10))
axes = axes.ravel()

for i in range(3):
  img = plt.imread(test_caries_path + '/' + random.choice(test_caries_image))
  axes[m].imshow(img)
  axes[m].set_title("Caries")
  m=m+1

for i in range(3):
  img = plt.imread(test_no_caries_path + '/' + random.choice(test_no_caries_image))
  axes[m].imshow(img)
  axes[m].set_title("No - Caries")
  m=m+1

# %% [markdown]
# # **Part - 3**

# %% [markdown]
# Model

# %%
# Model
model=tf.keras.applications.efficientnet_v2.EfficientNetV2B3(weights='imagenet',include_top=False)
# Design new model
x=model.output
x=tf.keras.layers.GlobalMaxPool2D()(x)
x=tf.keras.layers.Dense(512,activation='relu')(x)
x=tf.keras.layers.Dropout(0.3)(x)
x = tf.keras.layers.Dense(512, activation = 'relu')(x)
x=tf.keras.layers.Dropout(0.3)(x)
x = tf.keras.layers.Dense(1024, activation = 'relu')(x)
x=tf.keras.layers.Dropout(0.3)(x)
x = tf.keras.layers.Dense(1024, activation = 'relu')(x)
x=tf.keras.layers.Dropout(0.3)(x)
preds = tf.keras.layers.Dense(2, activation = 'softmax')(x)  # This layer will have output. So It will have only one neuron
efficent_model=tf.keras.models.Model(inputs = model.input, outputs = preds)
opt=tf.keras.optimizers.legacy.SGD(learning_rate=0.001, decay=1e-6, momentum=0.9, nesterov=True)
efficent_model.compile(loss=tf.keras.losses.categorical_crossentropy,optimizer=opt,metrics=['accuracy'])
efficent_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b3_notop.h5
# 52606240/52606240 [==============================] - 4s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  rescaling (Rescaling)          (None, None, None,   0           ['input_1[0][0]']
#                                 3)
#
#  normalization (Normalization)  (None, None, None,   0           ['rescaling[0][0]']
#                                 3)
#
#  stem_conv (Conv2D)             (None, None, None,   1080        ['normalization[0][0]']
#                                 40)
#
#  stem_bn (BatchNormalization)   (None, None, None,   160         ['stem_conv[0][0]']
#                                 40)
#
#  stem_activation (Activation)   (None, None, None,   0           ['stem_bn[0][0]']
#                                 40)
#
#  block1a_project_conv (Conv2D)  (None, None, None,   5760        ['stem_activation[0][0]']
#                                 16)
#
#  block1a_project_bn (BatchNorma  (None, None, None,   64         ['block1a_project_conv[0][0]']
#  lization)                      16)
#
#  block1a_project_activation (Ac  (None, None, None,   0          ['block1a_project_bn[0][0]']
#  tivation)                      16)
#
#  block1b_project_conv (Conv2D)  (None, None, None,   2304        ['block1a_project_activation[0][0
#                                 16)                              ]']
#
#  block1b_project_bn (BatchNorma  (None, None, None,   64         ['block1b_project_conv[0][0]']
#  lization)                      16)
#
#  block1b_project_activation (Ac  (None, None, None,   0          ['block1b_project_bn[0][0]']
#  tivation)                      16)
#
#  block1b_drop (Dropout)         (None, None, None,   0           ['block1b_project_activation[0][0
#                                 16)                              ]']
#
#  block1b_add (Add)              (None, None, None,   0           ['block1b_drop[0][0]',
#                                 16)                               'block1a_project_activation[0][0
#                                                                  ]']
#
#  block2a_expand_conv (Conv2D)   (None, None, None,   9216        ['block1b_add[0][0]']
#                                 64)
#
#  block2a_expand_bn (BatchNormal  (None, None, None,   256        ['block2a_expand_conv[0][0]']
#  ization)                       64)
#
#  block2a_expand_activation (Act  (None, None, None,   0          ['block2a_expand_bn[0][0]']
#  ivation)                       64)
#
#  block2a_project_conv (Conv2D)  (None, None, None,   2560        ['block2a_expand_activation[0][0]
#                                 40)                              ']
#
#  block2a_project_bn (BatchNorma  (None, None, None,   160        ['block2a_project_conv[0][0]']
#  lization)                      40)
#
#  block2b_expand_conv (Conv2D)   (None, None, None,   57600       ['block2a_project_bn[0][0]']
#                                 160)
#
#  block2b_expand_bn (BatchNormal  (None, None, None,   640        ['block2b_expand_conv[0][0]']
#  ization)                       160)
#
#  block2b_expand_activation (Act  (None, None, None,   0          ['block2b_expand_bn[0][0]']
#  ivation)                       160)
#
#  block2b_project_conv (Conv2D)  (None, None, None,   6400        ['block2b_expand_activation[0][0]
#                                 40)                              ']
#
#  block2b_project_bn (BatchNorma  (None, None, None,   160        ['block2b_project_conv[0][0]']
#  lization)                      40)
#
#  block2b_drop (Dropout)         (None, None, None,   0           ['block2b_project_bn[0][0]']
#                                 40)
#
#  block2b_add (Add)              (None, None, None,   0           ['block2b_drop[0][0]',
#                                 40)                               'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, None, None,   57600       ['block2b_add[0][0]']
#                                 160)
#
#  block2c_expand_bn (BatchNormal  (None, None, None,   640        ['block2c_expand_conv[0][0]']
#  ization)                       160)
#
#  block2c_expand_activation (Act  (None, None, None,   0          ['block2c_expand_bn[0][0]']
#  ivation)                       160)
#
#  block2c_project_conv (Conv2D)  (None, None, None,   6400        ['block2c_expand_activation[0][0]
#                                 40)                              ']
#
#  block2c_project_bn (BatchNorma  (None, None, None,   160        ['block2c_project_conv[0][0]']
#  lization)                      40)
#
#  block2c_drop (Dropout)         (None, None, None,   0           ['block2c_project_bn[0][0]']
#                                 40)
#
#  block2c_add (Add)              (None, None, None,   0           ['block2c_drop[0][0]',
#                                 40)                               'block2b_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, None, None,   57600       ['block2c_add[0][0]']
#                                 160)
#
#  block3a_expand_bn (BatchNormal  (None, None, None,   640        ['block3a_expand_conv[0][0]']
#  ization)                       160)
#
#  block3a_expand_activation (Act  (None, None, None,   0          ['block3a_expand_bn[0][0]']
#  ivation)                       160)
#
#  block3a_project_conv (Conv2D)  (None, None, None,   8960        ['block3a_expand_activation[0][0]
#                                 56)                              ']
#
#  block3a_project_bn (BatchNorma  (None, None, None,   224        ['block3a_project_conv[0][0]']
#  lization)                      56)
#
#  block3b_expand_conv (Conv2D)   (None, None, None,   112896      ['block3a_project_bn[0][0]']
#                                 224)
#
#  block3b_expand_bn (BatchNormal  (None, None, None,   896        ['block3b_expand_conv[0][0]']
#  ization)                       224)
#
#  block3b_expand_activation (Act  (None, None, None,   0          ['block3b_expand_bn[0][0]']
#  ivation)                       224)
#
#  block3b_project_conv (Conv2D)  (None, None, None,   12544       ['block3b_expand_activation[0][0]
#                                 56)                              ']
#
#  block3b_project_bn (BatchNorma  (None, None, None,   224        ['block3b_project_conv[0][0]']
#  lization)                      56)
#
#  block3b_drop (Dropout)         (None, None, None,   0           ['block3b_project_bn[0][0]']
#                                 56)
#
#  block3b_add (Add)              (None, None, None,   0           ['block3b_drop[0][0]',
#                                 56)                               'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, None, None,   112896      ['block3b_add[0][0]']
#                                 224)
#
#  block3c_expand_bn (BatchNormal  (None, None, None,   896        ['block3c_expand_conv[0][0]']
#  ization)                       224)
#
#  block3c_expand_activation (Act  (None, None, None,   0          ['block3c_expand_bn[0][0]']
#  ivation)                       224)
#
#  block3c_project_conv (Conv2D)  (None, None, None,   12544       ['block3c_expand_activation[0][0]
#                                 56)                              ']
#
#  block3c_project_bn (BatchNorma  (None, None, None,   224        ['block3c_project_conv[0][0]']
#  lization)                      56)
#
#  block3c_drop (Dropout)         (None, None, None,   0           ['block3c_project_bn[0][0]']
#                                 56)
#
#  block3c_add (Add)              (None, None, None,   0           ['block3c_drop[0][0]',
#                                 56)                               'block3b_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, None, None,   12544       ['block3c_add[0][0]']
#                                 224)
#
#  block4a_expand_bn (BatchNormal  (None, None, None,   896        ['block4a_expand_conv[0][0]']
#  ization)                       224)
#
#  block4a_expand_activation (Act  (None, None, None,   0          ['block4a_expand_bn[0][0]']
#  ivation)                       224)
#
#  block4a_dwconv2 (DepthwiseConv  (None, None, None,   2016       ['block4a_expand_activation[0][0]
#  2D)                            224)                             ']
#
#  block4a_bn (BatchNormalization  (None, None, None,   896        ['block4a_dwconv2[0][0]']
#  )                              224)
#
#  block4a_activation (Activation  (None, None, None,   0          ['block4a_bn[0][0]']
#  )                              224)
#
#  block4a_se_squeeze (GlobalAver  (None, 224)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 224)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 14)     3150        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 224)    3360        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, None, None,   0           ['block4a_activation[0][0]',
#                                 224)                              'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, None, None,   25088       ['block4a_se_excite[0][0]']
#                                 112)
#
#  block4a_project_bn (BatchNorma  (None, None, None,   448        ['block4a_project_conv[0][0]']
#  lization)                      112)
#
#  block4b_expand_conv (Conv2D)   (None, None, None,   50176       ['block4a_project_bn[0][0]']
#                                 448)
#
#  block4b_expand_bn (BatchNormal  (None, None, None,   1792       ['block4b_expand_conv[0][0]']
#  ization)                       448)
#
#  block4b_expand_activation (Act  (None, None, None,   0          ['block4b_expand_bn[0][0]']
#  ivation)                       448)
#
#  block4b_dwconv2 (DepthwiseConv  (None, None, None,   4032       ['block4b_expand_activation[0][0]
#  2D)                            448)                             ']
#
#  block4b_bn (BatchNormalization  (None, None, None,   1792       ['block4b_dwconv2[0][0]']
#  )                              448)
#
#  block4b_activation (Activation  (None, None, None,   0          ['block4b_bn[0][0]']
#  )                              448)
#
#  block4b_se_squeeze (GlobalAver  (None, 448)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 448)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 28)     12572       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 448)    12992       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, None, None,   0           ['block4b_activation[0][0]',
#                                 448)                              'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, None, None,   50176       ['block4b_se_excite[0][0]']
#                                 112)
#
#  block4b_project_bn (BatchNorma  (None, None, None,   448        ['block4b_project_conv[0][0]']
#  lization)                      112)
#
#  block4b_drop (Dropout)         (None, None, None,   0           ['block4b_project_bn[0][0]']
#                                 112)
#
#  block4b_add (Add)              (None, None, None,   0           ['block4b_drop[0][0]',
#                                 112)                              'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, None, None,   50176       ['block4b_add[0][0]']
#                                 448)
#
#  block4c_expand_bn (BatchNormal  (None, None, None,   1792       ['block4c_expand_conv[0][0]']
#  ization)                       448)
#
#  block4c_expand_activation (Act  (None, None, None,   0          ['block4c_expand_bn[0][0]']
#  ivation)                       448)
#
#  block4c_dwconv2 (DepthwiseConv  (None, None, None,   4032       ['block4c_expand_activation[0][0]
#  2D)                            448)                             ']
#
#  block4c_bn (BatchNormalization  (None, None, None,   1792       ['block4c_dwconv2[0][0]']
#  )                              448)
#
#  block4c_activation (Activation  (None, None, None,   0          ['block4c_bn[0][0]']
#  )                              448)
#
#  block4c_se_squeeze (GlobalAver  (None, 448)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 448)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 28)     12572       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 448)    12992       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, None, None,   0           ['block4c_activation[0][0]',
#                                 448)                              'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, None, None,   50176       ['block4c_se_excite[0][0]']
#                                 112)
#
#  block4c_project_bn (BatchNorma  (None, None, None,   448        ['block4c_project_conv[0][0]']
#  lization)                      112)
#
#  block4c_drop (Dropout)         (None, None, None,   0           ['block4c_project_bn[0][0]']
#                                 112)
#
#  block4c_add (Add)              (None, None, None,   0           ['block4c_drop[0][0]',
#                                 112)                              'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, None, None,   50176       ['block4c_add[0][0]']
#                                 448)
#
#  block4d_expand_bn (BatchNormal  (None, None, None,   1792       ['block4d_expand_conv[0][0]']
#  ization)                       448)
#
#  block4d_expand_activation (Act  (None, None, None,   0          ['block4d_expand_bn[0][0]']
#  ivation)                       448)
#
#  block4d_dwconv2 (DepthwiseConv  (None, None, None,   4032       ['block4d_expand_activation[0][0]
#  2D)                            448)                             ']
#
#  block4d_bn (BatchNormalization  (None, None, None,   1792       ['block4d_dwconv2[0][0]']
#  )                              448)
#
#  block4d_activation (Activation  (None, None, None,   0          ['block4d_bn[0][0]']
#  )                              448)
#
#  block4d_se_squeeze (GlobalAver  (None, 448)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 448)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 28)     12572       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 448)    12992       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, None, None,   0           ['block4d_activation[0][0]',
#                                 448)                              'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, None, None,   50176       ['block4d_se_excite[0][0]']
#                                 112)
#
#  block4d_project_bn (BatchNorma  (None, None, None,   448        ['block4d_project_conv[0][0]']
#  lization)                      112)
#
#  block4d_drop (Dropout)         (None, None, None,   0           ['block4d_project_bn[0][0]']
#                                 112)
#
#  block4d_add (Add)              (None, None, None,   0           ['block4d_drop[0][0]',
#                                 112)                              'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2D)   (None, None, None,   50176       ['block4d_add[0][0]']
#                                 448)
#
#  block4e_expand_bn (BatchNormal  (None, None, None,   1792       ['block4e_expand_conv[0][0]']
#  ization)                       448)
#
#  block4e_expand_activation (Act  (None, None, None,   0          ['block4e_expand_bn[0][0]']
#  ivation)                       448)
#
#  block4e_dwconv2 (DepthwiseConv  (None, None, None,   4032       ['block4e_expand_activation[0][0]
#  2D)                            448)                             ']
#
#  block4e_bn (BatchNormalization  (None, None, None,   1792       ['block4e_dwconv2[0][0]']
#  )                              448)
#
#  block4e_activation (Activation  (None, None, None,   0          ['block4e_bn[0][0]']
#  )                              448)
#
#  block4e_se_squeeze (GlobalAver  (None, 448)         0           ['block4e_activation[0][0]']
#  agePooling2D)
#
#  block4e_se_reshape (Reshape)   (None, 1, 1, 448)    0           ['block4e_se_squeeze[0][0]']
#
#  block4e_se_reduce (Conv2D)     (None, 1, 1, 28)     12572       ['block4e_se_reshape[0][0]']
#
#  block4e_se_expand (Conv2D)     (None, 1, 1, 448)    12992       ['block4e_se_reduce[0][0]']
#
#  block4e_se_excite (Multiply)   (None, None, None,   0           ['block4e_activation[0][0]',
#                                 448)                              'block4e_se_expand[0][0]']
#
#  block4e_project_conv (Conv2D)  (None, None, None,   50176       ['block4e_se_excite[0][0]']
#                                 112)
#
#  block4e_project_bn (BatchNorma  (None, None, None,   448        ['block4e_project_conv[0][0]']
#  lization)                      112)
#
#  block4e_drop (Dropout)         (None, None, None,   0           ['block4e_project_bn[0][0]']
#                                 112)
#
#  block4e_add (Add)              (None, None, None,   0           ['block4e_drop[0][0]',
#                                 112)                              'block4d_add[0][0]']
#
#  block5a_expand_conv (Conv2D)   (None, None, None,   75264       ['block4e_add[0][0]']
#                                 672)
#
#  block5a_expand_bn (BatchNormal  (None, None, None,   2688       ['block5a_expand_conv[0][0]']
#  ization)                       672)
#
#  block5a_expand_activation (Act  (None, None, None,   0          ['block5a_expand_bn[0][0]']
#  ivation)                       672)
#
#  block5a_dwconv2 (DepthwiseConv  (None, None, None,   6048       ['block5a_expand_activation[0][0]
#  2D)                            672)                             ']
#
#  block5a_bn (BatchNormalization  (None, None, None,   2688       ['block5a_dwconv2[0][0]']
#  )                              672)
#
#  block5a_activation (Activation  (None, None, None,   0          ['block5a_bn[0][0]']
#  )                              672)
#
#  block5a_se_squeeze (GlobalAver  (None, 672)         0           ['block5a_activation[0][0]']
#  agePooling2D)
#
#  block5a_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block5a_se_squeeze[0][0]']
#
#  block5a_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multiply)   (None, None, None,   0           ['block5a_activation[0][0]',
#                                 672)                              'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv2D)  (None, None, None,   91392       ['block5a_se_excite[0][0]']
#                                 136)
#
#  block5a_project_bn (BatchNorma  (None, None, None,   544        ['block5a_project_conv[0][0]']
#  lization)                      136)
#
#  block5b_expand_conv (Conv2D)   (None, None, None,   110976      ['block5a_project_bn[0][0]']
#                                 816)
#
#  block5b_expand_bn (BatchNormal  (None, None, None,   3264       ['block5b_expand_conv[0][0]']
#  ization)                       816)
#
#  block5b_expand_activation (Act  (None, None, None,   0          ['block5b_expand_bn[0][0]']
#  ivation)                       816)
#
#  block5b_dwconv2 (DepthwiseConv  (None, None, None,   7344       ['block5b_expand_activation[0][0]
#  2D)                            816)                             ']
#
#  block5b_bn (BatchNormalization  (None, None, None,   3264       ['block5b_dwconv2[0][0]']
#  )                              816)
#
#  block5b_activation (Activation  (None, None, None,   0          ['block5b_bn[0][0]']
#  )                              816)
#
#  block5b_se_squeeze (GlobalAver  (None, 816)         0           ['block5b_activation[0][0]']
#  agePooling2D)
#
#  block5b_se_reshape (Reshape)   (None, 1, 1, 816)    0           ['block5b_se_squeeze[0][0]']
#
#  block5b_se_reduce (Conv2D)     (None, 1, 1, 34)     27778       ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)     (None, 1, 1, 816)    28560       ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multiply)   (None, None, None,   0           ['block5b_activation[0][0]',
#                                 816)                              'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv2D)  (None, None, None,   110976      ['block5b_se_excite[0][0]']
#                                 136)
#
#  block5b_project_bn (BatchNorma  (None, None, None,   544        ['block5b_project_conv[0][0]']
#  lization)                      136)
#
#  block5b_drop (Dropout)         (None, None, None,   0           ['block5b_project_bn[0][0]']
#                                 136)
#
#  block5b_add (Add)              (None, None, None,   0           ['block5b_drop[0][0]',
#                                 136)                              'block5a_project_bn[0][0]']
#
#  block5c_expand_conv (Conv2D)   (None, None, None,   110976      ['block5b_add[0][0]']
#                                 816)
#
#  block5c_expand_bn (BatchNormal  (None, None, None,   3264       ['block5c_expand_conv[0][0]']
#  ization)                       816)
#
#  block5c_expand_activation (Act  (None, None, None,   0          ['block5c_expand_bn[0][0]']
#  ivation)                       816)
#
#  block5c_dwconv2 (DepthwiseConv  (None, None, None,   7344       ['block5c_expand_activation[0][0]
#  2D)                            816)                             ']
#
#  block5c_bn (BatchNormalization  (None, None, None,   3264       ['block5c_dwconv2[0][0]']
#  )                              816)
#
#  block5c_activation (Activation  (None, None, None,   0          ['block5c_bn[0][0]']
#  )                              816)
#
#  block5c_se_squeeze (GlobalAver  (None, 816)         0           ['block5c_activation[0][0]']
#  agePooling2D)
#
#  block5c_se_reshape (Reshape)   (None, 1, 1, 816)    0           ['block5c_se_squeeze[0][0]']
#
#  block5c_se_reduce (Conv2D)     (None, 1, 1, 34)     27778       ['block5c_se_reshape[0][0]']
#
#  block5c_se_expand (Conv2D)     (None, 1, 1, 816)    28560       ['block5c_se_reduce[0][0]']
#
#  block5c_se_excite (Multiply)   (None, None, None,   0           ['block5c_activation[0][0]',
#                                 816)                              'block5c_se_expand[0][0]']
#
#  block5c_project_conv (Conv2D)  (None, None, None,   110976      ['block5c_se_excite[0][0]']
#                                 136)
#
#  block5c_project_bn (BatchNorma  (None, None, None,   544        ['block5c_project_conv[0][0]']
#  lization)                      136)
#
#  block5c_drop (Dropout)         (None, None, None,   0           ['block5c_project_bn[0][0]']
#                                 136)
#
#  block5c_add (Add)              (None, None, None,   0           ['block5c_drop[0][0]',
# ...
#                                 232)                              'block6h_add[0][0]']
#
#  block6j_expand_conv (Conv2D)   (None, None, None,   322944      ['block6i_add[0][0]']
#                                 1392)
#
#  block6j_expand_bn (BatchNormal  (None, None, None,   5568       ['block6j_expand_conv[0][0]']
#  ization)                       1392)
#
#  block6j_expand_activation (Act  (None, None, None,   0          ['block6j_expand_bn[0][0]']
#  ivation)                       1392)
#
#  block6j_dwconv2 (DepthwiseConv  (None, None, None,   12528      ['block6j_expand_activation[0][0]
#  2D)                            1392)                            ']
#
#  block6j_bn (BatchNormalization  (None, None, None,   5568       ['block6j_dwconv2[0][0]']
#  )                              1392)
#
#  block6j_activation (Activation  (None, None, None,   0          ['block6j_bn[0][0]']
#  )                              1392)
#
#  block6j_se_squeeze (GlobalAver  (None, 1392)        0           ['block6j_activation[0][0]']
#  agePooling2D)
#
#  block6j_se_reshape (Reshape)   (None, 1, 1, 1392)   0           ['block6j_se_squeeze[0][0]']
#
#  block6j_se_reduce (Conv2D)     (None, 1, 1, 58)     80794       ['block6j_se_reshape[0][0]']
#
#  block6j_se_expand (Conv2D)     (None, 1, 1, 1392)   82128       ['block6j_se_reduce[0][0]']
#
#  block6j_se_excite (Multiply)   (None, None, None,   0           ['block6j_activation[0][0]',
#                                 1392)                             'block6j_se_expand[0][0]']
#
#  block6j_project_conv (Conv2D)  (None, None, None,   322944      ['block6j_se_excite[0][0]']
#                                 232)
#
#  block6j_project_bn (BatchNorma  (None, None, None,   928        ['block6j_project_conv[0][0]']
#  lization)                      232)
#
#  block6j_drop (Dropout)         (None, None, None,   0           ['block6j_project_bn[0][0]']
#                                 232)
#
#  block6j_add (Add)              (None, None, None,   0           ['block6j_drop[0][0]',
#                                 232)                              'block6i_add[0][0]']
#
#  block6k_expand_conv (Conv2D)   (None, None, None,   322944      ['block6j_add[0][0]']
#                                 1392)
#
#  block6k_expand_bn (BatchNormal  (None, None, None,   5568       ['block6k_expand_conv[0][0]']
#  ization)                       1392)
#
#  block6k_expand_activation (Act  (None, None, None,   0          ['block6k_expand_bn[0][0]']
#  ivation)                       1392)
#
#  block6k_dwconv2 (DepthwiseConv  (None, None, None,   12528      ['block6k_expand_activation[0][0]
#  2D)                            1392)                            ']
#
#  block6k_bn (BatchNormalization  (None, None, None,   5568       ['block6k_dwconv2[0][0]']
#  )                              1392)
#
#  block6k_activation (Activation  (None, None, None,   0          ['block6k_bn[0][0]']
#  )                              1392)
#
#  block6k_se_squeeze (GlobalAver  (None, 1392)        0           ['block6k_activation[0][0]']
#  agePooling2D)
#
#  block6k_se_reshape (Reshape)   (None, 1, 1, 1392)   0           ['block6k_se_squeeze[0][0]']
#
#  block6k_se_reduce (Conv2D)     (None, 1, 1, 58)     80794       ['block6k_se_reshape[0][0]']
#
#  block6k_se_expand (Conv2D)     (None, 1, 1, 1392)   82128       ['block6k_se_reduce[0][0]']
#
#  block6k_se_excite (Multiply)   (None, None, None,   0           ['block6k_activation[0][0]',
#                                 1392)                             'block6k_se_expand[0][0]']
#
#  block6k_project_conv (Conv2D)  (None, None, None,   322944      ['block6k_se_excite[0][0]']
#                                 232)
#
#  block6k_project_bn (BatchNorma  (None, None, None,   928        ['block6k_project_conv[0][0]']
#  lization)                      232)
#
#  block6k_drop (Dropout)         (None, None, None,   0           ['block6k_project_bn[0][0]']
#                                 232)
#
#  block6k_add (Add)              (None, None, None,   0           ['block6k_drop[0][0]',
#                                 232)                              'block6j_add[0][0]']
#
#  block6l_expand_conv (Conv2D)   (None, None, None,   322944      ['block6k_add[0][0]']
#                                 1392)
#
#  block6l_expand_bn (BatchNormal  (None, None, None,   5568       ['block6l_expand_conv[0][0]']
#  ization)                       1392)
#
#  block6l_expand_activation (Act  (None, None, None,   0          ['block6l_expand_bn[0][0]']
#  ivation)                       1392)
#
#  block6l_dwconv2 (DepthwiseConv  (None, None, None,   12528      ['block6l_expand_activation[0][0]
#  2D)                            1392)                            ']
#
#  block6l_bn (BatchNormalization  (None, None, None,   5568       ['block6l_dwconv2[0][0]']
#  )                              1392)
#
#  block6l_activation (Activation  (None, None, None,   0          ['block6l_bn[0][0]']
#  )                              1392)
#
#  block6l_se_squeeze (GlobalAver  (None, 1392)        0           ['block6l_activation[0][0]']
#  agePooling2D)
#
#  block6l_se_reshape (Reshape)   (None, 1, 1, 1392)   0           ['block6l_se_squeeze[0][0]']
#
#  block6l_se_reduce (Conv2D)     (None, 1, 1, 58)     80794       ['block6l_se_reshape[0][0]']
#
#  block6l_se_expand (Conv2D)     (None, 1, 1, 1392)   82128       ['block6l_se_reduce[0][0]']
#
#  block6l_se_excite (Multiply)   (None, None, None,   0           ['block6l_activation[0][0]',
#                                 1392)                             'block6l_se_expand[0][0]']
#
#  block6l_project_conv (Conv2D)  (None, None, None,   322944      ['block6l_se_excite[0][0]']
#                                 232)
#
#  block6l_project_bn (BatchNorma  (None, None, None,   928        ['block6l_project_conv[0][0]']
#  lization)                      232)
#
#  block6l_drop (Dropout)         (None, None, None,   0           ['block6l_project_bn[0][0]']
#                                 232)
#
#  block6l_add (Add)              (None, None, None,   0           ['block6l_drop[0][0]',
#                                 232)                              'block6k_add[0][0]']
#
#  top_conv (Conv2D)              (None, None, None,   356352      ['block6l_add[0][0]']
#                                 1536)
#
#  top_bn (BatchNormalization)    (None, None, None,   6144        ['top_conv[0][0]']
#                                 1536)
#
#  top_activation (Activation)    (None, None, None,   0           ['top_bn[0][0]']
#                                 1536)
#
#  global_max_pooling2d (GlobalMa  (None, 1536)        0           ['top_activation[0][0]']
#  xPooling2D)
#
#  dense (Dense)                  (None, 512)          786944      ['global_max_pooling2d[0][0]']
#
#  dropout (Dropout)              (None, 512)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 512)          262656      ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 512)          0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 1024)         525312      ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 1024)         0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 1024)         1049600     ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 1024)         0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 2)            2050        ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 15,557,184
# Trainable params: 15,447,968
# Non-trainable params: 109,216
# __________________________________________________________________________________________________

# %%
for i,layer in enumerate(efficent_model.layers):
  print(i,layer.name)
# Out:
# 0 input_1
# 1 rescaling
# 2 normalization
# 3 stem_conv
# 4 stem_bn
# 5 stem_activation
# 6 block1a_project_conv
# 7 block1a_project_bn
# 8 block1a_project_activation
# 9 block1b_project_conv
# 10 block1b_project_bn
# 11 block1b_project_activation
# 12 block1b_drop
# 13 block1b_add
# 14 block2a_expand_conv
# 15 block2a_expand_bn
# 16 block2a_expand_activation
# 17 block2a_project_conv
# 18 block2a_project_bn
# 19 block2b_expand_conv
# 20 block2b_expand_bn
# 21 block2b_expand_activation
# 22 block2b_project_conv
# 23 block2b_project_bn
# 24 block2b_drop
# 25 block2b_add
# 26 block2c_expand_conv
# 27 block2c_expand_bn
# 28 block2c_expand_activation
# 29 block2c_project_conv
# 30 block2c_project_bn
# 31 block2c_drop
# 32 block2c_add
# 33 block3a_expand_conv
# 34 block3a_expand_bn
# 35 block3a_expand_activation
# 36 block3a_project_conv
# 37 block3a_project_bn
# 38 block3b_expand_conv
# 39 block3b_expand_bn
# 40 block3b_expand_activation
# 41 block3b_project_conv
# 42 block3b_project_bn
# 43 block3b_drop
# 44 block3b_add
# 45 block3c_expand_conv
# 46 block3c_expand_bn
# 47 block3c_expand_activation
# 48 block3c_project_conv
# 49 block3c_project_bn
# 50 block3c_drop
# 51 block3c_add
# 52 block4a_expand_conv
# 53 block4a_expand_bn
# 54 block4a_expand_activation
# 55 block4a_dwconv2
# 56 block4a_bn
# 57 block4a_activation
# 58 block4a_se_squeeze
# 59 block4a_se_reshape
# 60 block4a_se_reduce
# 61 block4a_se_expand
# 62 block4a_se_excite
# 63 block4a_project_conv
# 64 block4a_project_bn
# 65 block4b_expand_conv
# 66 block4b_expand_bn
# 67 block4b_expand_activation
# 68 block4b_dwconv2
# 69 block4b_bn
# 70 block4b_activation
# 71 block4b_se_squeeze
# 72 block4b_se_reshape
# 73 block4b_se_reduce
# 74 block4b_se_expand
# 75 block4b_se_excite
# 76 block4b_project_conv
# 77 block4b_project_bn
# 78 block4b_drop
# 79 block4b_add
# 80 block4c_expand_conv
# 81 block4c_expand_bn
# 82 block4c_expand_activation
# 83 block4c_dwconv2
# 84 block4c_bn
# 85 block4c_activation
# 86 block4c_se_squeeze
# 87 block4c_se_reshape
# 88 block4c_se_reduce
# 89 block4c_se_expand
# 90 block4c_se_excite
# 91 block4c_project_conv
# 92 block4c_project_bn
# 93 block4c_drop
# 94 block4c_add
# 95 block4d_expand_conv
# 96 block4d_expand_bn
# 97 block4d_expand_activation
# 98 block4d_dwconv2
# 99 block4d_bn
# 100 block4d_activation
# 101 block4d_se_squeeze
# 102 block4d_se_reshape
# 103 block4d_se_reduce
# 104 block4d_se_expand
# 105 block4d_se_excite
# 106 block4d_project_conv
# 107 block4d_project_bn
# 108 block4d_drop
# 109 block4d_add
# 110 block4e_expand_conv
# 111 block4e_expand_bn
# 112 block4e_expand_activation
# 113 block4e_dwconv2
# 114 block4e_bn
# 115 block4e_activation
# 116 block4e_se_squeeze
# 117 block4e_se_reshape
# 118 block4e_se_reduce
# 119 block4e_se_expand
# 120 block4e_se_excite
# 121 block4e_project_conv
# 122 block4e_project_bn
# 123 block4e_drop
# 124 block4e_add
# 125 block5a_expand_conv
# 126 block5a_expand_bn
# 127 block5a_expand_activation
# 128 block5a_dwconv2
# 129 block5a_bn
# 130 block5a_activation
# 131 block5a_se_squeeze
# 132 block5a_se_reshape
# 133 block5a_se_reduce
# 134 block5a_se_expand
# 135 block5a_se_excite
# 136 block5a_project_conv
# 137 block5a_project_bn
# 138 block5b_expand_conv
# 139 block5b_expand_bn
# 140 block5b_expand_activation
# 141 block5b_dwconv2
# 142 block5b_bn
# 143 block5b_activation
# 144 block5b_se_squeeze
# 145 block5b_se_reshape
# 146 block5b_se_reduce
# 147 block5b_se_expand
# 148 block5b_se_excite
# 149 block5b_project_conv
# 150 block5b_project_bn
# 151 block5b_drop
# 152 block5b_add
# 153 block5c_expand_conv
# 154 block5c_expand_bn
# 155 block5c_expand_activation
# 156 block5c_dwconv2
# 157 block5c_bn
# 158 block5c_activation
# 159 block5c_se_squeeze
# 160 block5c_se_reshape
# 161 block5c_se_reduce
# 162 block5c_se_expand
# 163 block5c_se_excite
# 164 block5c_project_conv
# 165 block5c_project_bn
# 166 block5c_drop
# 167 block5c_add
# 168 block5d_expand_conv
# 169 block5d_expand_bn
# 170 block5d_expand_activation
# 171 block5d_dwconv2
# 172 block5d_bn
# 173 block5d_activation
# 174 block5d_se_squeeze
# 175 block5d_se_reshape
# 176 block5d_se_reduce
# 177 block5d_se_expand
# 178 block5d_se_excite
# 179 block5d_project_conv
# 180 block5d_project_bn
# 181 block5d_drop
# 182 block5d_add
# 183 block5e_expand_conv
# 184 block5e_expand_bn
# 185 block5e_expand_activation
# 186 block5e_dwconv2
# 187 block5e_bn
# 188 block5e_activation
# 189 block5e_se_squeeze
# 190 block5e_se_reshape
# 191 block5e_se_reduce
# 192 block5e_se_expand
# 193 block5e_se_excite
# 194 block5e_project_conv
# 195 block5e_project_bn
# 196 block5e_drop
# 197 block5e_add
# 198 block5f_expand_conv
# 199 block5f_expand_bn
# 200 block5f_expand_activation
# 201 block5f_dwconv2
# 202 block5f_bn
# 203 block5f_activation
# 204 block5f_se_squeeze
# 205 block5f_se_reshape
# 206 block5f_se_reduce
# 207 block5f_se_expand
# 208 block5f_se_excite
# 209 block5f_project_conv
# 210 block5f_project_bn
# 211 block5f_drop
# 212 block5f_add
# 213 block5g_expand_conv
# 214 block5g_expand_bn
# 215 block5g_expand_activation
# 216 block5g_dwconv2
# 217 block5g_bn
# 218 block5g_activation
# 219 block5g_se_squeeze
# 220 block5g_se_reshape
# 221 block5g_se_reduce
# 222 block5g_se_expand
# 223 block5g_se_excite
# 224 block5g_project_conv
# 225 block5g_project_bn
# 226 block5g_drop
# 227 block5g_add
# 228 block6a_expand_conv
# 229 block6a_expand_bn
# 230 block6a_expand_activation
# 231 block6a_dwconv2
# 232 block6a_bn
# 233 block6a_activation
# 234 block6a_se_squeeze
# 235 block6a_se_reshape
# 236 block6a_se_reduce
# 237 block6a_se_expand
# 238 block6a_se_excite
# 239 block6a_project_conv
# 240 block6a_project_bn
# 241 block6b_expand_conv
# 242 block6b_expand_bn
# 243 block6b_expand_activation
# 244 block6b_dwconv2
# 245 block6b_bn
# 246 block6b_activation
# 247 block6b_se_squeeze
# 248 block6b_se_reshape
# 249 block6b_se_reduce
# 250 block6b_se_expand
# 251 block6b_se_excite
# 252 block6b_project_conv
# 253 block6b_project_bn
# 254 block6b_drop
# 255 block6b_add
# 256 block6c_expand_conv
# 257 block6c_expand_bn
# 258 block6c_expand_activation
# 259 block6c_dwconv2
# 260 block6c_bn
# 261 block6c_activation
# 262 block6c_se_squeeze
# 263 block6c_se_reshape
# 264 block6c_se_reduce
# 265 block6c_se_expand
# 266 block6c_se_excite
# 267 block6c_project_conv
# 268 block6c_project_bn
# 269 block6c_drop
# 270 block6c_add
# 271 block6d_expand_conv
# 272 block6d_expand_bn
# 273 block6d_expand_activation
# 274 block6d_dwconv2
# 275 block6d_bn
# 276 block6d_activation
# 277 block6d_se_squeeze
# 278 block6d_se_reshape
# 279 block6d_se_reduce
# 280 block6d_se_expand
# 281 block6d_se_excite
# 282 block6d_project_conv
# 283 block6d_project_bn
# 284 block6d_drop
# 285 block6d_add
# 286 block6e_expand_conv
# 287 block6e_expand_bn
# 288 block6e_expand_activation
# 289 block6e_dwconv2
# 290 block6e_bn
# 291 block6e_activation
# 292 block6e_se_squeeze
# 293 block6e_se_reshape
# 294 block6e_se_reduce
# 295 block6e_se_expand
# 296 block6e_se_excite
# 297 block6e_project_conv
# 298 block6e_project_bn
# 299 block6e_drop
# 300 block6e_add
# 301 block6f_expand_conv
# 302 block6f_expand_bn
# 303 block6f_expand_activation
# 304 block6f_dwconv2
# 305 block6f_bn
# 306 block6f_activation
# 307 block6f_se_squeeze
# 308 block6f_se_reshape
# 309 block6f_se_reduce
# 310 block6f_se_expand
# 311 block6f_se_excite
# 312 block6f_project_conv
# 313 block6f_project_bn
# 314 block6f_drop
# 315 block6f_add
# 316 block6g_expand_conv
# 317 block6g_expand_bn
# 318 block6g_expand_activation
# 319 block6g_dwconv2
# 320 block6g_bn
# 321 block6g_activation
# 322 block6g_se_squeeze
# 323 block6g_se_reshape
# 324 block6g_se_reduce
# 325 block6g_se_expand
# 326 block6g_se_excite
# 327 block6g_project_conv
# 328 block6g_project_bn
# 329 block6g_drop
# 330 block6g_add
# 331 block6h_expand_conv
# 332 block6h_expand_bn
# 333 block6h_expand_activation
# 334 block6h_dwconv2
# 335 block6h_bn
# 336 block6h_activation
# 337 block6h_se_squeeze
# 338 block6h_se_reshape
# 339 block6h_se_reduce
# 340 block6h_se_expand
# 341 block6h_se_excite
# 342 block6h_project_conv
# 343 block6h_project_bn
# 344 block6h_drop
# 345 block6h_add
# 346 block6i_expand_conv
# 347 block6i_expand_bn
# 348 block6i_expand_activation
# 349 block6i_dwconv2
# 350 block6i_bn
# 351 block6i_activation
# 352 block6i_se_squeeze
# 353 block6i_se_reshape
# 354 block6i_se_reduce
# 355 block6i_se_expand
# 356 block6i_se_excite
# 357 block6i_project_conv
# 358 block6i_project_bn
# 359 block6i_drop
# 360 block6i_add
# 361 block6j_expand_conv
# 362 block6j_expand_bn
# 363 block6j_expand_activation
# 364 block6j_dwconv2
# 365 block6j_bn
# 366 block6j_activation
# 367 block6j_se_squeeze
# 368 block6j_se_reshape
# 369 block6j_se_reduce
# 370 block6j_se_expand
# 371 block6j_se_excite
# 372 block6j_project_conv
# 373 block6j_project_bn
# 374 block6j_drop
# 375 block6j_add
# 376 block6k_expand_conv
# 377 block6k_expand_bn
# 378 block6k_expand_activation
# 379 block6k_dwconv2
# 380 block6k_bn
# 381 block6k_activation
# 382 block6k_se_squeeze
# 383 block6k_se_reshape
# 384 block6k_se_reduce
# 385 block6k_se_expand
# 386 block6k_se_excite
# 387 block6k_project_conv
# 388 block6k_project_bn
# 389 block6k_drop
# 390 block6k_add
# 391 block6l_expand_conv
# 392 block6l_expand_bn
# 393 block6l_expand_activation
# 394 block6l_dwconv2
# 395 block6l_bn
# 396 block6l_activation
# 397 block6l_se_squeeze
# 398 block6l_se_reshape
# 399 block6l_se_reduce
# 400 block6l_se_expand
# 401 block6l_se_excite
# 402 block6l_project_conv
# 403 block6l_project_bn
# 404 block6l_drop
# 405 block6l_add
# 406 top_conv
# 407 top_bn
# 408 top_activation
# 409 global_max_pooling2d
# 410 dense
# 411 dropout
# 412 dense_1
# 413 dropout_1
# 414 dense_2
# 415 dropout_2
# 416 dense_3
# 417 dropout_3
# 418 dense_4

# %%
# set layers for training
#layer upto 419 is already trained

for layer in efficent_model.layers[:419]:
  layer.trainable=False
for layer in efficent_model.layers[419:]:
  layer.trainable=True

# %%
# prepare Training data
train_generator=ImageDataGenerator()
#train_generator=ImageDataGenerator(preprocessing_function=tf.keras.applications.efficientnet_v2.preprocess_input)
train_data=train_generator.flow_from_directory("/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/training",target_size=(150,150),class_mode='categorical', shuffle=True)
# Out:
# Found 1080 images belonging to 2 classes.

# %%
# prepare Validation data
valid_generator=ImageDataGenerator()
valid_data=valid_generator.flow_from_directory("/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/validation",target_size=(150,150),class_mode='categorical',shuffle=True)
# Out:
# Found 422 images belonging to 2 classes.

# %%
# prepare Test data
test_generator=ImageDataGenerator()
test_data=test_generator.flow_from_directory("/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/test",target_size=(224,224),class_mode='categorical',shuffle=True)
# Out:
# Found 292 images belonging to 2 classes.

# %%
train_data.class_indices
# Out:
# {'caries': 0, 'no-caries': 1}

# %%
valid_data.class_indices
# Out:
# {'caries': 0, 'no-caries': 1}

# %%
test_data.class_indices
# Out:
# {'caries': 0, 'no-caries': 1}

# %%
hist=efficent_model.fit(train_data, epochs=60,validation_data=valid_data)
# Out:
# Epoch 1/60
# 34/34 [==============================] - 323s 9s/step - loss: 0.7644 - accuracy: 0.6630 - val_loss: 0.5707 - val_accuracy: 0.7488
# Epoch 2/60
# 34/34 [==============================] - 8s 242ms/step - loss: 0.5399 - accuracy: 0.7426 - val_loss: 0.3786 - val_accuracy: 0.8507
# Epoch 3/60
# 34/34 [==============================] - 8s 228ms/step - loss: 0.3369 - accuracy: 0.8528 - val_loss: 0.2735 - val_accuracy: 0.8744
# Epoch 4/60
# 34/34 [==============================] - 10s 280ms/step - loss: 0.2013 - accuracy: 0.9167 - val_loss: 0.2427 - val_accuracy: 0.9052
# Epoch 5/60
# 34/34 [==============================] - 9s 269ms/step - loss: 0.1496 - accuracy: 0.9444 - val_loss: 0.1294 - val_accuracy: 0.9526
# Epoch 6/60
# 34/34 [==============================] - 8s 223ms/step - loss: 0.0888 - accuracy: 0.9704 - val_loss: 0.1438 - val_accuracy: 0.9526
# Epoch 7/60
# 34/34 [==============================] - 8s 237ms/step - loss: 0.0469 - accuracy: 0.9833 - val_loss: 0.1394 - val_accuracy: 0.9550
# Epoch 8/60
# 34/34 [==============================] - 8s 229ms/step - loss: 0.0363 - accuracy: 0.9852 - val_loss: 0.1631 - val_accuracy: 0.9479
# Epoch 9/60
# 34/34 [==============================] - 8s 221ms/step - loss: 0.0579 - accuracy: 0.9815 - val_loss: 0.1211 - val_accuracy: 0.9573
# Epoch 10/60
# 34/34 [==============================] - 8s 240ms/step - loss: 0.0456 - accuracy: 0.9861 - val_loss: 0.1160 - val_accuracy: 0.9550
# Epoch 11/60
# 34/34 [==============================] - 9s 263ms/step - loss: 0.0520 - accuracy: 0.9880 - val_loss: 0.1058 - val_accuracy: 0.9645
# Epoch 12/60
# 34/34 [==============================] - 8s 229ms/step - loss: 0.0212 - accuracy: 0.9935 - val_loss: 0.1452 - val_accuracy: 0.9573
# Epoch 13/60
# 34/34 [==============================] - 8s 246ms/step - loss: 0.0261 - accuracy: 0.9907 - val_loss: 0.0845 - val_accuracy: 0.9716
# Epoch 14/60
# 34/34 [==============================] - 8s 225ms/step - loss: 0.0338 - accuracy: 0.9880 - val_loss: 0.1130 - val_accuracy: 0.9621
# Epoch 15/60
# 34/34 [==============================] - 8s 240ms/step - loss: 0.0063 - accuracy: 0.9991 - val_loss: 0.0963 - val_accuracy: 0.9668
# Epoch 16/60
# 34/34 [==============================] - 9s 263ms/step - loss: 0.0223 - accuracy: 0.9944 - val_loss: 0.0774 - val_accuracy: 0.9716
# Epoch 17/60
# 34/34 [==============================] - 8s 226ms/step - loss: 0.0097 - accuracy: 0.9954 - val_loss: 0.1143 - val_accuracy: 0.9621
# Epoch 18/60
# 34/34 [==============================] - 8s 243ms/step - loss: 0.0048 - accuracy: 0.9991 - val_loss: 0.0964 - val_accuracy: 0.9645
# Epoch 19/60
# 34/34 [==============================] - 9s 263ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.1174 - val_accuracy: 0.9668
# Epoch 20/60
# 34/34 [==============================] - 9s 264ms/step - loss: 0.0079 - accuracy: 0.9981 - val_loss: 0.1048 - val_accuracy: 0.9645
# Epoch 21/60
# 34/34 [==============================] - 8s 239ms/step - loss: 0.0111 - accuracy: 0.9954 - val_loss: 0.0860 - val_accuracy: 0.9716
# Epoch 22/60
# 34/34 [==============================] - 8s 227ms/step - loss: 0.0130 - accuracy: 0.9935 - val_loss: 0.1047 - val_accuracy: 0.9692
# Epoch 23/60
# 34/34 [==============================] - 8s 224ms/step - loss: 0.0171 - accuracy: 0.9935 - val_loss: 0.1089 - val_accuracy: 0.9668
# Epoch 24/60
# 34/34 [==============================] - 8s 230ms/step - loss: 0.0105 - accuracy: 0.9963 - val_loss: 0.0551 - val_accuracy: 0.9739
# Epoch 25/60
# 34/34 [==============================] - 8s 242ms/step - loss: 0.0052 - accuracy: 0.9972 - val_loss: 0.0963 - val_accuracy: 0.9716
# Epoch 26/60
# 34/34 [==============================] - 8s 226ms/step - loss: 0.0055 - accuracy: 0.9991 - val_loss: 0.1864 - val_accuracy: 0.9526
# Epoch 27/60
# 34/34 [==============================] - 8s 233ms/step - loss: 0.0156 - accuracy: 0.9963 - val_loss: 0.0394 - val_accuracy: 0.9834
# Epoch 28/60
# 34/34 [==============================] - 8s 245ms/step - loss: 0.0078 - accuracy: 0.9991 - val_loss: 0.0394 - val_accuracy: 0.9810
# Epoch 29/60
# 34/34 [==============================] - 8s 224ms/step - loss: 0.0019 - accuracy: 0.9991 - val_loss: 0.0631 - val_accuracy: 0.9787
# Epoch 30/60
# 34/34 [==============================] - 8s 241ms/step - loss: 0.0103 - accuracy: 0.9954 - val_loss: 0.0645 - val_accuracy: 0.9716
# Epoch 31/60
# 34/34 [==============================] - 9s 262ms/step - loss: 0.0060 - accuracy: 0.9981 - val_loss: 0.0691 - val_accuracy: 0.9716
# Epoch 32/60
# 34/34 [==============================] - 8s 224ms/step - loss: 0.0121 - accuracy: 0.9963 - val_loss: 0.0483 - val_accuracy: 0.9810
# Epoch 33/60
# 34/34 [==============================] - 8s 245ms/step - loss: 0.0058 - accuracy: 0.9991 - val_loss: 0.0947 - val_accuracy: 0.9668
# Epoch 34/60
# 34/34 [==============================] - 9s 263ms/step - loss: 0.0059 - accuracy: 0.9991 - val_loss: 0.1110 - val_accuracy: 0.9668
# Epoch 35/60
# 34/34 [==============================] - 8s 223ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.0695 - val_accuracy: 0.9810
# Epoch 36/60
# 34/34 [==============================] - 8s 239ms/step - loss: 0.0046 - accuracy: 0.9981 - val_loss: 0.0965 - val_accuracy: 0.9739
# Epoch 37/60
# 34/34 [==============================] - 8s 227ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0475 - val_accuracy: 0.9787
# Epoch 38/60
# 34/34 [==============================] - 8s 225ms/step - loss: 0.0019 - accuracy: 0.9991 - val_loss: 0.0619 - val_accuracy: 0.9810
# Epoch 39/60
# 34/34 [==============================] - 8s 242ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0567 - val_accuracy: 0.9810
# Epoch 40/60
# 34/34 [==============================] - 9s 263ms/step - loss: 0.0014 - accuracy: 0.9991 - val_loss: 0.0882 - val_accuracy: 0.9763
# Epoch 41/60
# 34/34 [==============================] - 8s 224ms/step - loss: 0.0021 - accuracy: 0.9991 - val_loss: 0.0737 - val_accuracy: 0.9787
# Epoch 42/60
# 34/34 [==============================] - 8s 241ms/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 0.0807 - val_accuracy: 0.9810
# Epoch 43/60
# 34/34 [==============================] - 9s 262ms/step - loss: 0.0053 - accuracy: 0.9991 - val_loss: 0.0703 - val_accuracy: 0.9810
# Epoch 44/60
# 34/34 [==============================] - 8s 227ms/step - loss: 0.0160 - accuracy: 0.9963 - val_loss: 0.0926 - val_accuracy: 0.9787
# Epoch 45/60
# 34/34 [==============================] - 8s 240ms/step - loss: 0.0040 - accuracy: 0.9981 - val_loss: 0.0576 - val_accuracy: 0.9834
# Epoch 46/60
# 34/34 [==============================] - 8s 223ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0616 - val_accuracy: 0.9834
# Epoch 47/60
# 34/34 [==============================] - 8s 242ms/step - loss: 0.0031 - accuracy: 0.9981 - val_loss: 0.0729 - val_accuracy: 0.9810
# Epoch 48/60
# 34/34 [==============================] - 9s 262ms/step - loss: 0.0014 - accuracy: 0.9991 - val_loss: 0.1003 - val_accuracy: 0.9739
# Epoch 49/60
# 34/34 [==============================] - 8s 225ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.0827 - val_accuracy: 0.9787
# Epoch 50/60
# 34/34 [==============================] - 8s 242ms/step - loss: 0.0069 - accuracy: 0.9972 - val_loss: 0.0283 - val_accuracy: 0.9858
# Epoch 51/60
# 34/34 [==============================] - 8s 224ms/step - loss: 0.0028 - accuracy: 0.9981 - val_loss: 0.0400 - val_accuracy: 0.9882
# Epoch 52/60
# 34/34 [==============================] - 8s 240ms/step - loss: 0.0033 - accuracy: 0.9981 - val_loss: 0.0391 - val_accuracy: 0.9882
# Epoch 53/60
# 34/34 [==============================] - 9s 263ms/step - loss: 6.1492e-04 - accuracy: 1.0000 - val_loss: 0.0431 - val_accuracy: 0.9834
# Epoch 54/60
# 34/34 [==============================] - 8s 223ms/step - loss: 9.4950e-04 - accuracy: 1.0000 - val_loss: 0.0560 - val_accuracy: 0.9810
# Epoch 55/60
# 34/34 [==============================] - 8s 239ms/step - loss: 5.3385e-04 - accuracy: 1.0000 - val_loss: 0.0527 - val_accuracy: 0.9858
# Epoch 56/60
# 34/34 [==============================] - 8s 223ms/step - loss: 5.9039e-04 - accuracy: 1.0000 - val_loss: 0.0541 - val_accuracy: 0.9834
# Epoch 57/60
# 34/34 [==============================] - 8s 239ms/step - loss: 0.0051 - accuracy: 0.9981 - val_loss: 0.0619 - val_accuracy: 0.9858
# Epoch 58/60
# 34/34 [==============================] - 8s 240ms/step - loss: 0.0020 - accuracy: 0.9991 - val_loss: 0.0401 - val_accuracy: 0.9882
# Epoch 59/60
# 34/34 [==============================] - 8s 228ms/step - loss: 0.0080 - accuracy: 0.9963 - val_loss: 0.0900 - val_accuracy: 0.9763
# Epoch 60/60
# 34/34 [==============================] - 8s 240ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0913 - val_accuracy: 0.9763

# %%
final_model=efficent_model.save("efficientnetv3b3.h5")

# %% [markdown]
# # **Part - 4**

# %%
plt.plot(hist.history['loss'], label='Training loss')
plt.plot(hist.history['val_loss'], label='Test loss')
plt.xlabel("Epoches")
plt.ylabel("Training loss")
plt.title("Training v/s Test Loss Progress")
plt.legend()

# %%
plt.plot(hist.history['accuracy'], label='Training Accuracy')
plt.plot(hist.history['val_accuracy'], label='Test Accuracy')
plt.xlabel("Epoches")
plt.ylabel("Training Accuracy")
plt.title("Training v/s Test Accuracy progress")
plt.legend()

# %% [markdown]
# # **Part - 5**

# %% [markdown]
# Training Data

# %%
# prepare Training data
train_generator=ImageDataGenerator()
#train_generator=ImageDataGenerator(preprocessing_function=tf.keras.applications.efficientnet_v2.preprocess_input)
train_data_1 = train_generator.flow_from_directory("/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/training",target_size=(150,150),class_mode='categorical',batch_size=32, shuffle=False)
# Out:
# Found 1080 images belonging to 2 classes.

# %%
train_data_1.classes
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int32)

# %%
# Training Data
actual_train_class=train_data_1.classes
actual_valid_class=valid_data.classes
from sklearn.metrics import confusion_matrix
train_data_1.reset()
y_train_pred = efficent_model.predict(train_data_1)
y_train_pred =np.argmax(y_train_pred, axis=1)
# Out:
# 34/34 [==============================] - 9s 158ms/step

# %%
cm = confusion_matrix(actual_train_class, y_train_pred)
sns.heatmap(cm, annot=True,fmt='d', xticklabels=['Caries','No Caries'], yticklabels=['Caries','No Caries'],cbar=False)

from sklearn.metrics import accuracy_score, classification_report
accuracy_score(actual_train_class, y_train_pred)
# Out:
# 1.0

# %%
print(classification_report(actual_train_class, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       765
#            1       1.00      1.00      1.00       315
#
#     accuracy                           1.00      1080
#    macro avg       1.00      1.00      1.00      1080
# weighted avg       1.00      1.00      1.00      1080

# %%
print(efficent_model.evaluate(train_data_1))
# Out:
# 34/34 [==============================] - 3s 97ms/step - loss: 2.1784e-06 - accuracy: 1.0000
# [2.1784255750390003e-06, 1.0]

# %% [markdown]
# Validation Data

# %%
# prepare Validation data
valid_generator=ImageDataGenerator()
valid_data_1 = valid_generator.flow_from_directory("/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/validation",target_size=(150,150),class_mode='categorical',shuffle=False,batch_size=32)
# Out:
# Found 422 images belonging to 2 classes.

# %%
actual_valid_class=valid_data_1.classes

y_valid_pred = efficent_model.predict(valid_data_1)
y_valid_pred =np.argmax(y_valid_pred, axis=1)

cm = confusion_matrix(actual_valid_class, y_valid_pred)
sns.heatmap(cm, annot=True,fmt='d', xticklabels=['Caries','No Caries'], yticklabels=['Caries','No Caries'],cbar=False)
# Out:
# 14/14 [==============================] - 1s 90ms/step
# <Axes: >

# %%
print(classification_report(actual_valid_class, y_valid_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98       211
#            1       1.00      0.95      0.98       211
#
#     accuracy                           0.98       422
#    macro avg       0.98      0.98      0.98       422
# weighted avg       0.98      0.98      0.98       422

# %%
print(efficent_model.evaluate(valid_data_1))
# Out:
# 14/14 [==============================] - 1s 93ms/step - loss: 0.0913 - accuracy: 0.9763
# [0.09130892157554626, 0.9763033390045166]

# %% [markdown]
# Test Data

# %%
# prepare Test data
test_generator=ImageDataGenerator()
test_data_1 = test_generator.flow_from_directory("/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/test",target_size=(150,150),class_mode='categorical',shuffle=False,batch_size=32)
# Out:
# Found 292 images belonging to 2 classes.

# %%
actual_test_class=test_data_1.classes

y_test_pred = efficent_model.predict(test_data_1)
y_test_pred =np.argmax(y_test_pred, axis=1)

cm = confusion_matrix(actual_test_class, y_test_pred)
sns.heatmap(cm, annot=True,fmt='d', xticklabels=['Caries','No Caries'], yticklabels=['Caries','No Caries'],cbar=False)
# Out:
# 10/10 [==============================] - 47s 5s/step
# <Axes: >

# %%
print(classification_report(actual_test_class, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97       210
#            1       1.00      0.85      0.92        82
#
#     accuracy                           0.96       292
#    macro avg       0.97      0.93      0.95       292
# weighted avg       0.96      0.96      0.96       292

# %%
print(efficent_model.evaluate(test_data_1))
# Out:
# 10/10 [==============================] - 1s 121ms/step - loss: 0.1772 - accuracy: 0.9589
# [0.1772354692220688, 0.9589040875434875]

# %% [markdown]
# # **Part - 6**

# %% [markdown]
# Training

# %%
from tensorflow.keras.preprocessing.image import img_to_array
fig, axes=plt.subplots(2,3, figsize=(10,10))
axes=axes.ravel()
plt.subplots_adjust(hspace=0.4)

i=0
for j in train_caries_image:
  if(i<=2):
    test_img=load_img(train_caries_path+'/'+j, target_size=(150,150))
    axes[i].imshow(test_img)
    test_img=img_to_array(test_img)
    test_imag= test_img.reshape(1,150,150,3)
   
    pred=efficent_model.predict(test_imag)
    pred= np.argmax(pred)
    if pred==0:
      result='Caries'
    elif pred==1:
      result='Without Caries'

    axes[i].set_title("Actual: Caries \n Predicted: {}".format(result))
    axes[i].axis('off')
    i=i+1
    
for j in train_no_caries_image:
  if(i>2 and i <6):
    test_img=load_img(train_no_caries_path+'/'+j, target_size=(150,150))
    axes[i].imshow(test_img)
    test_img=img_to_array(test_img)
    test_imag= test_img.reshape(1,150,150,3)
  
    pred=efficent_model.predict(test_imag)
    pred= np.argmax(pred)
    if pred==0:
      result='Caries'
    elif pred==1:
      result='Without Caries'

    axes[i].set_title("Actual: Without Caries \n Predicted: {}".format(result))
    axes[i].axis('off')
    i=i+1
 

fig.tight_layout()
fig.tight_layout()
fig.tight_layout()
fig.tight_layout()
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step

# %% [markdown]
# Validation

# %%
from tensorflow.keras.preprocessing.image import img_to_array
fig, axes=plt.subplots(2,3, figsize=(10,10))
axes=axes.ravel()
plt.subplots_adjust(hspace=0.4)

i=0
for j in valid_caries_image:
  if(i<=2):
    test_img=load_img(valid_caries_path+'/'+j, target_size=(150,150))
    axes[i].imshow(test_img)
    test_img=img_to_array(test_img)
    test_imag= test_img.reshape(1,150,150,3)
   
    pred=efficent_model.predict(test_imag)
    pred= np.argmax(pred)
    if pred==0:
      result='Caries'
    elif pred==1:
      result='Without Caries'

    axes[i].set_title("Actual: Caries \n Predicted: {}".format(result))
    axes[i].axis('off')
    i=i+1
    
for j in valid_no_caries_image:
  if(i>2 and i <6):
    test_img=load_img(valid_no_caries_path+'/'+j, target_size=(150,150))
    axes[i].imshow(test_img)
    test_img=img_to_array(test_img)
    test_imag= test_img.reshape(1,150,150,3)
  
    pred=efficent_model.predict(test_imag)
    pred= np.argmax(pred)
    if pred==0:
      result='Caries'
    elif pred==1:
      result='Without Caries'

    axes[i].set_title("Actual: Without Caries \n Predicted: {}".format(result))
    axes[i].axis('off')
    i=i+1
 

fig.tight_layout()
fig.tight_layout()
fig.tight_layout()
fig.tight_layout()
# Out:
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step

# %% [markdown]
# Test

# %%
from tensorflow.keras.preprocessing.image import img_to_array
fig, axes=plt.subplots(2,3, figsize=(10,10))
axes=axes.ravel()
plt.subplots_adjust(hspace=0.4)

i=0
for j in test_caries_image:
  if(i<=2):
    test_img=load_img(test_caries_path+'/'+j, target_size=(150,150))
    axes[i].imshow(test_img)
    test_img=img_to_array(test_img)
    test_imag= test_img.reshape(1,150,150,3)
   
    pred=efficent_model.predict(test_imag)
    pred= np.argmax(pred)
    if pred==0:
      result='Caries'
    elif pred==1:
      result='Without Caries'

    axes[i].set_title("Actual: Caries \n Predicted: {}".format(result))
    axes[i].axis('off')
    i=i+1
    
for j in test_no_caries_image:
  if(i>2 and i <6):
    test_img=load_img(test_no_caries_path+'/'+j, target_size=(150,150))
    axes[i].imshow(test_img)
    test_img=img_to_array(test_img)
    test_imag= test_img.reshape(1,150,150,3)
  
    pred=efficent_model.predict(test_imag)
    pred= np.argmax(pred)
    if pred==0:
      result='Caries'
    elif pred==1:
      result='Without Caries'

    axes[i].set_title("Actual: Without Caries \n Predicted: {}".format(result))
    axes[i].axis('off')
    i=i+1
 

fig.tight_layout()
fig.tight_layout()
fig.tight_layout()
fig.tight_layout()
# Out:
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 66ms/step
