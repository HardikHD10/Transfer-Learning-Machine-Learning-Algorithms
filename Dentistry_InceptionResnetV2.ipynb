# %% [markdown]
# # **Part - 1**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import tensorflow as tf
import tensorflow
from tensorflow.keras.preprocessing.image import load_img, ImageDataGenerator
import cv2
import time
import random
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Activation

# %%
# Path to Datasets
# Training Path
train_caries_path = "/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/training/caries"
train_no_caries_path = "/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/training/no-caries"

# Testing Path 
valid_caries_path = "/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/validation/caries"
valid_no_caries_path = "/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/validation/no-caries"

# Testing Path 
test_caries_path = "/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/test/caries"
test_no_caries_path = "/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/test/no-caries"

# %%
# Making Directory of Images
# Training Images
train_caries_image = os.listdir(train_caries_path)
train_no_caries_image = os.listdir(train_no_caries_path)

#Validation Images
valid_caries_image = os.listdir(valid_caries_path)
valid_no_caries_image = os.listdir(valid_no_caries_path)

#Testing Images
test_caries_image = os.listdir(test_caries_path)
test_no_caries_image = os.listdir(test_no_caries_path)

# %%
# Printing Numbers of Images in each Dataset
print("Number of Caries Images in Training = ",len(train_caries_image))
print("Number of No Caries Images in Training = ",len(train_no_caries_image))

print('\n')
print("Number of Caries Images in Validation = ",len(valid_caries_image))
print("Number of No Caries Images in Validation = ",len(valid_no_caries_image))

print('\n')
print("Number of Caries Images in Testing = ",len(test_caries_image))
print("Number of No Caries Images in Testing = ",len(test_no_caries_image))
# Out:
# Number of Caries Images in Training =  765
# Number of No Caries Images in Training =  315
#
#
# Number of Caries Images in Validation =  211
# Number of No Caries Images in Validation =  211
#
#
# Number of Caries Images in Testing =  210
# Number of No Caries Images in Testing =  82

# %% [markdown]
# # **Part - 2**

# %% [markdown]
# Training Data

# %%
m=0
fig, axes = plt.subplots(2,3, figsize=(10,10))
axes = axes.ravel()

for i in range(3):
  img = plt.imread(train_caries_path + '/' + random.choice(train_caries_image))
  axes[m].imshow(img)
  axes[m].set_title("Caries")
  m=m+1

for i in range(3):
  img = plt.imread(train_no_caries_path + '/' + random.choice(train_no_caries_image))
  axes[m].imshow(img)
  axes[m].set_title("No - Caries")
  m=m+1

# %% [markdown]
# Validation Data

# %%
m=0
fig, axes = plt.subplots(2,3, figsize=(10,10))
axes = axes.ravel()

for i in range(3):
  img = plt.imread(valid_caries_path + '/' + random.choice(valid_caries_image))
  axes[m].imshow(img)
  axes[m].set_title("Caries")
  m=m+1

for i in range(3):
  img = plt.imread(valid_no_caries_path + '/' + random.choice(valid_no_caries_image))
  axes[m].imshow(img)
  axes[m].set_title("No - Caries")
  m=m+1

# %% [markdown]
# Test Data

# %%
m=0
fig, axes = plt.subplots(2,3, figsize=(10,10))
axes = axes.ravel()

for i in range(3):
  img = plt.imread(test_caries_path + '/' + random.choice(test_caries_image))
  axes[m].imshow(img)
  axes[m].set_title("Caries")
  m=m+1

for i in range(3):
  img = plt.imread(test_no_caries_path + '/' + random.choice(test_no_caries_image))
  axes[m].imshow(img)
  axes[m].set_title("No - Caries")
  m=m+1

# %% [markdown]
# # **Part - 3**

# %% [markdown]
# Model

# %%
# Model
model=tf.keras.applications.InceptionResNetV2(weights='imagenet',include_top=False)
# Design new model
x=model.output
x=tf.keras.layers.GlobalMaxPool2D()(x)
x=tf.keras.layers.Dense(512,activation='relu')(x)
x=tf.keras.layers.Dropout(0.3)(x)
x = tf.keras.layers.Dense(512, activation = 'relu')(x)
x=tf.keras.layers.Dropout(0.3)(x)
x = tf.keras.layers.Dense(1024, activation = 'relu')(x)
x=tf.keras.layers.Dropout(0.3)(x)
x = tf.keras.layers.Dense(1024, activation = 'relu')(x)
x=tf.keras.layers.Dropout(0.3)(x)
preds = tf.keras.layers.Dense(2, activation = 'softmax')(x)  # This layer will have output. So It will have only one neuron
efficent_model=tf.keras.models.Model(inputs = model.input, outputs = preds)
opt=tf.keras.optimizers.legacy.SGD(learning_rate=0.001, decay=1e-6, momentum=0.9, nesterov=True)
efficent_model.compile(loss=tf.keras.losses.categorical_crossentropy,optimizer=opt,metrics=['accuracy'])
efficent_model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  conv2d_1218 (Conv2D)           (None, None, None,   864         ['input_7[0][0]']
#                                 32)
#
#  batch_normalization_1218 (Batc  (None, None, None,   96         ['conv2d_1218[0][0]']
#  hNormalization)                32)
#
#  activation_1218 (Activation)   (None, None, None,   0           ['batch_normalization_1218[0][0]'
#                                 32)                              ]
#
#  conv2d_1219 (Conv2D)           (None, None, None,   9216        ['activation_1218[0][0]']
#                                 32)
#
#  batch_normalization_1219 (Batc  (None, None, None,   96         ['conv2d_1219[0][0]']
#  hNormalization)                32)
#
#  activation_1219 (Activation)   (None, None, None,   0           ['batch_normalization_1219[0][0]'
#                                 32)                              ]
#
#  conv2d_1220 (Conv2D)           (None, None, None,   18432       ['activation_1219[0][0]']
#                                 64)
#
#  batch_normalization_1220 (Batc  (None, None, None,   192        ['conv2d_1220[0][0]']
#  hNormalization)                64)
#
#  activation_1220 (Activation)   (None, None, None,   0           ['batch_normalization_1220[0][0]'
#                                 64)                              ]
#
#  max_pooling2d_24 (MaxPooling2D  (None, None, None,   0          ['activation_1220[0][0]']
#  )                              64)
#
#  conv2d_1221 (Conv2D)           (None, None, None,   5120        ['max_pooling2d_24[0][0]']
#                                 80)
#
#  batch_normalization_1221 (Batc  (None, None, None,   240        ['conv2d_1221[0][0]']
#  hNormalization)                80)
#
#  activation_1221 (Activation)   (None, None, None,   0           ['batch_normalization_1221[0][0]'
#                                 80)                              ]
#
#  conv2d_1222 (Conv2D)           (None, None, None,   138240      ['activation_1221[0][0]']
#                                 192)
#
#  batch_normalization_1222 (Batc  (None, None, None,   576        ['conv2d_1222[0][0]']
#  hNormalization)                192)
#
#  activation_1222 (Activation)   (None, None, None,   0           ['batch_normalization_1222[0][0]'
#                                 192)                             ]
#
#  max_pooling2d_25 (MaxPooling2D  (None, None, None,   0          ['activation_1222[0][0]']
#  )                              192)
#
#  conv2d_1226 (Conv2D)           (None, None, None,   12288       ['max_pooling2d_25[0][0]']
#                                 64)
#
#  batch_normalization_1226 (Batc  (None, None, None,   192        ['conv2d_1226[0][0]']
#  hNormalization)                64)
#
#  activation_1226 (Activation)   (None, None, None,   0           ['batch_normalization_1226[0][0]'
#                                 64)                              ]
#
#  conv2d_1224 (Conv2D)           (None, None, None,   9216        ['max_pooling2d_25[0][0]']
#                                 48)
#
#  conv2d_1227 (Conv2D)           (None, None, None,   55296       ['activation_1226[0][0]']
#                                 96)
#
#  batch_normalization_1224 (Batc  (None, None, None,   144        ['conv2d_1224[0][0]']
#  hNormalization)                48)
#
#  batch_normalization_1227 (Batc  (None, None, None,   288        ['conv2d_1227[0][0]']
#  hNormalization)                96)
#
#  activation_1224 (Activation)   (None, None, None,   0           ['batch_normalization_1224[0][0]'
#                                 48)                              ]
#
#  activation_1227 (Activation)   (None, None, None,   0           ['batch_normalization_1227[0][0]'
#                                 96)                              ]
#
#  average_pooling2d_6 (AveragePo  (None, None, None,   0          ['max_pooling2d_25[0][0]']
#  oling2D)                       192)
#
#  conv2d_1223 (Conv2D)           (None, None, None,   18432       ['max_pooling2d_25[0][0]']
#                                 96)
#
#  conv2d_1225 (Conv2D)           (None, None, None,   76800       ['activation_1224[0][0]']
#                                 64)
#
#  conv2d_1228 (Conv2D)           (None, None, None,   82944       ['activation_1227[0][0]']
#                                 96)
#
#  conv2d_1229 (Conv2D)           (None, None, None,   12288       ['average_pooling2d_6[0][0]']
#                                 64)
#
#  batch_normalization_1223 (Batc  (None, None, None,   288        ['conv2d_1223[0][0]']
#  hNormalization)                96)
#
#  batch_normalization_1225 (Batc  (None, None, None,   192        ['conv2d_1225[0][0]']
#  hNormalization)                64)
#
#  batch_normalization_1228 (Batc  (None, None, None,   288        ['conv2d_1228[0][0]']
#  hNormalization)                96)
#
#  batch_normalization_1229 (Batc  (None, None, None,   192        ['conv2d_1229[0][0]']
#  hNormalization)                64)
#
#  activation_1223 (Activation)   (None, None, None,   0           ['batch_normalization_1223[0][0]'
#                                 96)                              ]
#
#  activation_1225 (Activation)   (None, None, None,   0           ['batch_normalization_1225[0][0]'
#                                 64)                              ]
#
#  activation_1228 (Activation)   (None, None, None,   0           ['batch_normalization_1228[0][0]'
#                                 96)                              ]
#
#  activation_1229 (Activation)   (None, None, None,   0           ['batch_normalization_1229[0][0]'
#                                 64)                              ]
#
#  mixed_5b (Concatenate)         (None, None, None,   0           ['activation_1223[0][0]',
#                                 320)                              'activation_1225[0][0]',
#                                                                   'activation_1228[0][0]',
#                                                                   'activation_1229[0][0]']
#
#  conv2d_1233 (Conv2D)           (None, None, None,   10240       ['mixed_5b[0][0]']
#                                 32)
#
#  batch_normalization_1233 (Batc  (None, None, None,   96         ['conv2d_1233[0][0]']
#  hNormalization)                32)
#
#  activation_1233 (Activation)   (None, None, None,   0           ['batch_normalization_1233[0][0]'
#                                 32)                              ]
#
#  conv2d_1231 (Conv2D)           (None, None, None,   10240       ['mixed_5b[0][0]']
#                                 32)
#
#  conv2d_1234 (Conv2D)           (None, None, None,   13824       ['activation_1233[0][0]']
#                                 48)
#
#  batch_normalization_1231 (Batc  (None, None, None,   96         ['conv2d_1231[0][0]']
#  hNormalization)                32)
#
#  batch_normalization_1234 (Batc  (None, None, None,   144        ['conv2d_1234[0][0]']
#  hNormalization)                48)
#
#  activation_1231 (Activation)   (None, None, None,   0           ['batch_normalization_1231[0][0]'
#                                 32)                              ]
#
#  activation_1234 (Activation)   (None, None, None,   0           ['batch_normalization_1234[0][0]'
#                                 48)                              ]
#
#  conv2d_1230 (Conv2D)           (None, None, None,   10240       ['mixed_5b[0][0]']
#                                 32)
#
#  conv2d_1232 (Conv2D)           (None, None, None,   9216        ['activation_1231[0][0]']
#                                 32)
#
#  conv2d_1235 (Conv2D)           (None, None, None,   27648       ['activation_1234[0][0]']
#                                 64)
#
#  batch_normalization_1230 (Batc  (None, None, None,   96         ['conv2d_1230[0][0]']
#  hNormalization)                32)
#
#  batch_normalization_1232 (Batc  (None, None, None,   96         ['conv2d_1232[0][0]']
#  hNormalization)                32)
#
#  batch_normalization_1235 (Batc  (None, None, None,   192        ['conv2d_1235[0][0]']
#  hNormalization)                64)
#
#  activation_1230 (Activation)   (None, None, None,   0           ['batch_normalization_1230[0][0]'
#                                 32)                              ]
#
#  activation_1232 (Activation)   (None, None, None,   0           ['batch_normalization_1232[0][0]'
#                                 32)                              ]
#
#  activation_1235 (Activation)   (None, None, None,   0           ['batch_normalization_1235[0][0]'
#                                 64)                              ]
#
#  block35_1_mixed (Concatenate)  (None, None, None,   0           ['activation_1230[0][0]',
#                                 128)                              'activation_1232[0][0]',
#                                                                   'activation_1235[0][0]']
#
#  block35_1_conv (Conv2D)        (None, None, None,   41280       ['block35_1_mixed[0][0]']
#                                 320)
#
#  block35_1 (Lambda)             (None, None, None,   0           ['mixed_5b[0][0]',
#                                 320)                              'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, None, None,   0           ['block35_1[0][0]']
#                                 320)
#
#  conv2d_1239 (Conv2D)           (None, None, None,   10240       ['block35_1_ac[0][0]']
#                                 32)
#
#  batch_normalization_1239 (Batc  (None, None, None,   96         ['conv2d_1239[0][0]']
#  hNormalization)                32)
#
#  activation_1239 (Activation)   (None, None, None,   0           ['batch_normalization_1239[0][0]'
#                                 32)                              ]
#
#  conv2d_1237 (Conv2D)           (None, None, None,   10240       ['block35_1_ac[0][0]']
#                                 32)
#
#  conv2d_1240 (Conv2D)           (None, None, None,   13824       ['activation_1239[0][0]']
#                                 48)
#
#  batch_normalization_1237 (Batc  (None, None, None,   96         ['conv2d_1237[0][0]']
#  hNormalization)                32)
#
#  batch_normalization_1240 (Batc  (None, None, None,   144        ['conv2d_1240[0][0]']
#  hNormalization)                48)
#
#  activation_1237 (Activation)   (None, None, None,   0           ['batch_normalization_1237[0][0]'
#                                 32)                              ]
#
#  activation_1240 (Activation)   (None, None, None,   0           ['batch_normalization_1240[0][0]'
#                                 48)                              ]
#
#  conv2d_1236 (Conv2D)           (None, None, None,   10240       ['block35_1_ac[0][0]']
#                                 32)
#
#  conv2d_1238 (Conv2D)           (None, None, None,   9216        ['activation_1237[0][0]']
#                                 32)
#
#  conv2d_1241 (Conv2D)           (None, None, None,   27648       ['activation_1240[0][0]']
#                                 64)
#
#  batch_normalization_1236 (Batc  (None, None, None,   96         ['conv2d_1236[0][0]']
#  hNormalization)                32)
#
#  batch_normalization_1238 (Batc  (None, None, None,   96         ['conv2d_1238[0][0]']
#  hNormalization)                32)
#
#  batch_normalization_1241 (Batc  (None, None, None,   192        ['conv2d_1241[0][0]']
#  hNormalization)                64)
#
#  activation_1236 (Activation)   (None, None, None,   0           ['batch_normalization_1236[0][0]'
#                                 32)                              ]
#
#  activation_1238 (Activation)   (None, None, None,   0           ['batch_normalization_1238[0][0]'
#                                 32)                              ]
#
#  activation_1241 (Activation)   (None, None, None,   0           ['batch_normalization_1241[0][0]'
#                                 64)                              ]
#
#  block35_2_mixed (Concatenate)  (None, None, None,   0           ['activation_1236[0][0]',
#                                 128)                              'activation_1238[0][0]',
#                                                                   'activation_1241[0][0]']
#
#  block35_2_conv (Conv2D)        (None, None, None,   41280       ['block35_2_mixed[0][0]']
#                                 320)
#
#  block35_2 (Lambda)             (None, None, None,   0           ['block35_1_ac[0][0]',
#                                 320)                              'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, None, None,   0           ['block35_2[0][0]']
#                                 320)
#
#  conv2d_1245 (Conv2D)           (None, None, None,   10240       ['block35_2_ac[0][0]']
#                                 32)
#
#  batch_normalization_1245 (Batc  (None, None, None,   96         ['conv2d_1245[0][0]']
#  hNormalization)                32)
#
#  activation_1245 (Activation)   (None, None, None,   0           ['batch_normalization_1245[0][0]'
#                                 32)                              ]
#
#  conv2d_1243 (Conv2D)           (None, None, None,   10240       ['block35_2_ac[0][0]']
#                                 32)
#
#  conv2d_1246 (Conv2D)           (None, None, None,   13824       ['activation_1245[0][0]']
#                                 48)
#
#  batch_normalization_1243 (Batc  (None, None, None,   96         ['conv2d_1243[0][0]']
#  hNormalization)                32)
#
#  batch_normalization_1246 (Batc  (None, None, None,   144        ['conv2d_1246[0][0]']
#  hNormalization)                48)
#
#  activation_1243 (Activation)   (None, None, None,   0           ['batch_normalization_1243[0][0]'
#                                 32)                              ]
#
#  activation_1246 (Activation)   (None, None, None,   0           ['batch_normalization_1246[0][0]'
#                                 48)                              ]
#
#  conv2d_1242 (Conv2D)           (None, None, None,   10240       ['block35_2_ac[0][0]']
#                                 32)
#
#  conv2d_1244 (Conv2D)           (None, None, None,   9216        ['activation_1243[0][0]']
#                                 32)
#
#  conv2d_1247 (Conv2D)           (None, None, None,   27648       ['activation_1246[0][0]']
#                                 64)
#
#  batch_normalization_1242 (Batc  (None, None, None,   96         ['conv2d_1242[0][0]']
#  hNormalization)                32)
#
#  batch_normalization_1244 (Batc  (None, None, None,   96         ['conv2d_1244[0][0]']
#  hNormalization)                32)
#
#  batch_normalization_1247 (Batc  (None, None, None,   192        ['conv2d_1247[0][0]']
#  hNormalization)                64)
#
#  activation_1242 (Activation)   (None, None, None,   0           ['batch_normalization_1242[0][0]'
#                                 32)                              ]
#
#  activation_1244 (Activation)   (None, None, None,   0           ['batch_normalization_1244[0][0]'
#                                 32)                              ]
#
#  activation_1247 (Activation)   (None, None, None,   0           ['batch_normalization_1247[0][0]'
#                                 64)                              ]
#
#  block35_3_mixed (Concatenate)  (None, None, None,   0           ['activation_1242[0][0]',
#                                 128)                              'activation_1244[0][0]',
#                                                                   'activation_1247[0][0]']
#
#  block35_3_conv (Conv2D)        (None, None, None,   41280       ['block35_3_mixed[0][0]']
#                                 320)
#
#  block35_3 (Lambda)             (None, None, None,   0           ['block35_2_ac[0][0]',
#                                 320)                              'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, None, None,   0           ['block35_3[0][0]']
#                                 320)
#
#  conv2d_1251 (Conv2D)           (None, None, None,   10240       ['block35_3_ac[0][0]']
#                                 32)
#
#  batch_normalization_1251 (Batc  (None, None, None,   96         ['conv2d_1251[0][0]']
#  hNormalization)                32)
#
#  activation_1251 (Activation)   (None, None, None,   0           ['batch_normalization_1251[0][0]'
#                                 32)                              ]
#
#  conv2d_1249 (Conv2D)           (None, None, None,   10240       ['block35_3_ac[0][0]']
#                                 32)
#
#  conv2d_1252 (Conv2D)           (None, None, None,   13824       ['activation_1251[0][0]']
#                                 48)
#
#  batch_normalization_1249 (Batc  (None, None, None,   96         ['conv2d_1249[0][0]']
#  hNormalization)                32)
#
#  batch_normalization_1252 (Batc  (None, None, None,   144        ['conv2d_1252[0][0]']
#  hNormalization)                48)
#
#  activation_1249 (Activation)   (None, None, None,   0           ['batch_normalization_1249[0][0]'
#                                 32)                              ]
#
#  activation_1252 (Activation)   (None, None, None,   0           ['batch_normalization_1252[0][0]'
#                                 48)                              ]
#
#  conv2d_1248 (Conv2D)           (None, None, None,   10240       ['block35_3_ac[0][0]']
#                                 32)
#
#  conv2d_1250 (Conv2D)           (None, None, None,   9216        ['activation_1249[0][0]']
#                                 32)
#
#  conv2d_1253 (Conv2D)           (None, None, None,   27648       ['activation_1252[0][0]']
#                                 64)
#
#  batch_normalization_1248 (Batc  (None, None, None,   96         ['conv2d_1248[0][0]']
#  hNormalization)                32)
#
#  batch_normalization_1250 (Batc  (None, None, None,   96         ['conv2d_1250[0][0]']
#  hNormalization)                32)
#
#  batch_normalization_1253 (Batc  (None, None, None,   192        ['conv2d_1253[0][0]']
#  hNormalization)                64)
#
#  activation_1248 (Activation)   (None, None, None,   0           ['batch_normalization_1248[0][0]'
#                                 32)                              ]
#
#  activation_1250 (Activation)   (None, None, None,   0           ['batch_normalization_1250[0][0]'
#                                 32)                              ]
#
#  activation_1253 (Activation)   (None, None, None,   0           ['batch_normalization_1253[0][0]'
#                                 64)                              ]
#
#  block35_4_mixed (Concatenate)  (None, None, None,   0           ['activation_1248[0][0]',
#                                 128)                              'activation_1250[0][0]',
#                                                                   'activation_1253[0][0]']
#
#  block35_4_conv (Conv2D)        (None, None, None,   41280       ['block35_4_mixed[0][0]']
#                                 320)
#
#  block35_4 (Lambda)             (None, None, None,   0           ['block35_3_ac[0][0]',
#                                 320)                              'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, None, None,   0           ['block35_4[0][0]']
#                                 320)
#
#  conv2d_1257 (Conv2D)           (None, None, None,   10240       ['block35_4_ac[0][0]']
#                                 32)
#
#  batch_normalization_1257 (Batc  (None, None, None,   96         ['conv2d_1257[0][0]']
#  hNormalization)                32)
#
#  activation_1257 (Activation)   (None, None, None,   0           ['batch_normalization_1257[0][0]'
#                                 32)                              ]
#
#  conv2d_1255 (Conv2D)           (None, None, None,   10240       ['block35_4_ac[0][0]']
#                                 32)
#
#  conv2d_1258 (Conv2D)           (None, None, None,   13824       ['activation_1257[0][0]']
#                                 48)
#
#  batch_normalization_1255 (Batc  (None, None, None,   96         ['conv2d_1255[0][0]']
#  hNormalization)                32)
#
#  batch_normalization_1258 (Batc  (None, None, None,   144        ['conv2d_1258[0][0]']
#  hNormalization)                48)
#
#  activation_1255 (Activation)   (None, None, None,   0           ['batch_normalization_1255[0][0]'
#                                 32)                              ]
#
#  activation_1258 (Activation)   (None, None, None,   0           ['batch_normalization_1258[0][0]'
#                                 48)                              ]
#
#  conv2d_1254 (Conv2D)           (None, None, None,   10240       ['block35_4_ac[0][0]']
#                                 32)
#
#  conv2d_1256 (Conv2D)           (None, None, None,   9216        ['activation_1255[0][0]']
#                                 32)
#
#  conv2d_1259 (Conv2D)           (None, None, None,   27648       ['activation_1258[0][0]']
#                                 64)
#
#  batch_normalization_1254 (Batc  (None, None, None,   96         ['conv2d_1254[0][0]']
#  hNormalization)                32)
#
#  batch_normalization_1256 (Batc  (None, None, None,   96         ['conv2d_1256[0][0]']
#  hNormalization)                32)
#
#  batch_normalization_1259 (Batc  (None, None, None,   192        ['conv2d_1259[0][0]']
#  hNormalization)                64)
#
#  activation_1254 (Activation)   (None, None, None,   0           ['batch_normalization_1254[0][0]'
#                                 32)                              ]
#
#  activation_1256 (Activation)   (None, None, None,   0           ['batch_normalization_1256[0][0]'
#                                 32)                              ]
#
#  activation_1259 (Activation)   (None, None, None,   0           ['batch_normalization_1259[0][0]'
#                                 64)                              ]
#
#  block35_5_mixed (Concatenate)  (None, None, None,   0           ['activation_1254[0][0]',
#                                 128)                              'activation_1256[0][0]',
#                                                                   'activation_1259[0][0]']
#
#  block35_5_conv (Conv2D)        (None, None, None,   41280       ['block35_5_mixed[0][0]']
#                                 320)
#
#  block35_5 (Lambda)             (None, None, None,   0           ['block35_4_ac[0][0]',
#                                 320)                              'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, None, None,   0           ['block35_5[0][0]']
#                                 320)
#
#  conv2d_1263 (Conv2D)           (None, None, None,   10240       ['block35_5_ac[0][0]']
#                                 32)
#
#  batch_normalization_1263 (Batc  (None, None, None,   96         ['conv2d_1263[0][0]']
#  hNormalization)                32)
#
#  activation_1263 (Activation)   (None, None, None,   0           ['batch_normalization_1263[0][0]'
#                                 32)                              ]
#
#  conv2d_1261 (Conv2D)           (None, None, None,   10240       ['block35_5_ac[0][0]']
#                                 32)
#
#  conv2d_1264 (Conv2D)           (None, None, None,   13824       ['activation_1263[0][0]']
#                                 48)
#
#  batch_normalization_1261 (Batc  (None, None, None,   96         ['conv2d_1261[0][0]']
#  hNormalization)                32)
#
#  batch_normalization_1264 (Batc  (None, None, None,   144        ['conv2d_1264[0][0]']
#  hNormalization)                48)
#
# ...
#  hNormalization)                224)
#
#  activation_1411 (Activation)   (None, None, None,   0           ['batch_normalization_1411[0][0]'
#                                 224)                             ]
#
#  conv2d_1409 (Conv2D)           (None, None, None,   399360      ['block8_7_ac[0][0]']
#                                 192)
#
#  conv2d_1412 (Conv2D)           (None, None, None,   172032      ['activation_1411[0][0]']
#                                 256)
#
#  batch_normalization_1409 (Batc  (None, None, None,   576        ['conv2d_1409[0][0]']
#  hNormalization)                192)
#
#  batch_normalization_1412 (Batc  (None, None, None,   768        ['conv2d_1412[0][0]']
#  hNormalization)                256)
#
#  activation_1409 (Activation)   (None, None, None,   0           ['batch_normalization_1409[0][0]'
#                                 192)                             ]
#
#  activation_1412 (Activation)   (None, None, None,   0           ['batch_normalization_1412[0][0]'
#                                 256)                             ]
#
#  block8_8_mixed (Concatenate)   (None, None, None,   0           ['activation_1409[0][0]',
#                                 448)                              'activation_1412[0][0]']
#
#  block8_8_conv (Conv2D)         (None, None, None,   933920      ['block8_8_mixed[0][0]']
#                                 2080)
#
#  block8_8 (Lambda)              (None, None, None,   0           ['block8_7_ac[0][0]',
#                                 2080)                             'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)       (None, None, None,   0           ['block8_8[0][0]']
#                                 2080)
#
#  conv2d_1414 (Conv2D)           (None, None, None,   399360      ['block8_8_ac[0][0]']
#                                 192)
#
#  batch_normalization_1414 (Batc  (None, None, None,   576        ['conv2d_1414[0][0]']
#  hNormalization)                192)
#
#  activation_1414 (Activation)   (None, None, None,   0           ['batch_normalization_1414[0][0]'
#                                 192)                             ]
#
#  conv2d_1415 (Conv2D)           (None, None, None,   129024      ['activation_1414[0][0]']
#                                 224)
#
#  batch_normalization_1415 (Batc  (None, None, None,   672        ['conv2d_1415[0][0]']
#  hNormalization)                224)
#
#  activation_1415 (Activation)   (None, None, None,   0           ['batch_normalization_1415[0][0]'
#                                 224)                             ]
#
#  conv2d_1413 (Conv2D)           (None, None, None,   399360      ['block8_8_ac[0][0]']
#                                 192)
#
#  conv2d_1416 (Conv2D)           (None, None, None,   172032      ['activation_1415[0][0]']
#                                 256)
#
#  batch_normalization_1413 (Batc  (None, None, None,   576        ['conv2d_1413[0][0]']
#  hNormalization)                192)
#
#  batch_normalization_1416 (Batc  (None, None, None,   768        ['conv2d_1416[0][0]']
#  hNormalization)                256)
#
#  activation_1413 (Activation)   (None, None, None,   0           ['batch_normalization_1413[0][0]'
#                                 192)                             ]
#
#  activation_1416 (Activation)   (None, None, None,   0           ['batch_normalization_1416[0][0]'
#                                 256)                             ]
#
#  block8_9_mixed (Concatenate)   (None, None, None,   0           ['activation_1413[0][0]',
#                                 448)                              'activation_1416[0][0]']
#
#  block8_9_conv (Conv2D)         (None, None, None,   933920      ['block8_9_mixed[0][0]']
#                                 2080)
#
#  block8_9 (Lambda)              (None, None, None,   0           ['block8_8_ac[0][0]',
#                                 2080)                             'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)       (None, None, None,   0           ['block8_9[0][0]']
#                                 2080)
#
#  conv2d_1418 (Conv2D)           (None, None, None,   399360      ['block8_9_ac[0][0]']
#                                 192)
#
#  batch_normalization_1418 (Batc  (None, None, None,   576        ['conv2d_1418[0][0]']
#  hNormalization)                192)
#
#  activation_1418 (Activation)   (None, None, None,   0           ['batch_normalization_1418[0][0]'
#                                 192)                             ]
#
#  conv2d_1419 (Conv2D)           (None, None, None,   129024      ['activation_1418[0][0]']
#                                 224)
#
#  batch_normalization_1419 (Batc  (None, None, None,   672        ['conv2d_1419[0][0]']
#  hNormalization)                224)
#
#  activation_1419 (Activation)   (None, None, None,   0           ['batch_normalization_1419[0][0]'
#                                 224)                             ]
#
#  conv2d_1417 (Conv2D)           (None, None, None,   399360      ['block8_9_ac[0][0]']
#                                 192)
#
#  conv2d_1420 (Conv2D)           (None, None, None,   172032      ['activation_1419[0][0]']
#                                 256)
#
#  batch_normalization_1417 (Batc  (None, None, None,   576        ['conv2d_1417[0][0]']
#  hNormalization)                192)
#
#  batch_normalization_1420 (Batc  (None, None, None,   768        ['conv2d_1420[0][0]']
#  hNormalization)                256)
#
#  activation_1417 (Activation)   (None, None, None,   0           ['batch_normalization_1417[0][0]'
#                                 192)                             ]
#
#  activation_1420 (Activation)   (None, None, None,   0           ['batch_normalization_1420[0][0]'
#                                 256)                             ]
#
#  block8_10_mixed (Concatenate)  (None, None, None,   0           ['activation_1417[0][0]',
#                                 448)                              'activation_1420[0][0]']
#
#  block8_10_conv (Conv2D)        (None, None, None,   933920      ['block8_10_mixed[0][0]']
#                                 2080)
#
#  block8_10 (Lambda)             (None, None, None,   0           ['block8_9_ac[0][0]',
#                                 2080)                             'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)               (None, None, None,   3194880     ['block8_10[0][0]']
#                                 1536)
#
#  conv_7b_bn (BatchNormalization  (None, None, None,   4608       ['conv_7b[0][0]']
#  )                              1536)
#
#  conv_7b_ac (Activation)        (None, None, None,   0           ['conv_7b_bn[0][0]']
#                                 1536)
#
#  global_max_pooling2d_6 (Global  (None, 1536)        0           ['conv_7b_ac[0][0]']
#  MaxPooling2D)
#
#  dense_30 (Dense)               (None, 512)          786944      ['global_max_pooling2d_6[0][0]']
#
#  dropout_24 (Dropout)           (None, 512)          0           ['dense_30[0][0]']
#
#  dense_31 (Dense)               (None, 512)          262656      ['dropout_24[0][0]']
#
#  dropout_25 (Dropout)           (None, 512)          0           ['dense_31[0][0]']
#
#  dense_32 (Dense)               (None, 1024)         525312      ['dropout_25[0][0]']
#
#  dropout_26 (Dropout)           (None, 1024)         0           ['dense_32[0][0]']
#
#  dense_33 (Dense)               (None, 1024)         1049600     ['dropout_26[0][0]']
#
#  dropout_27 (Dropout)           (None, 1024)         0           ['dense_33[0][0]']
#
#  dense_34 (Dense)               (None, 2)            2050        ['dropout_27[0][0]']
#
# ==================================================================================================
# Total params: 56,963,298
# Trainable params: 56,902,754
# Non-trainable params: 60,544
# __________________________________________________________________________________________________

# %%
for i,layer in enumerate(efficent_model.layers):
  print(i,layer.name)
# Out:
# 0 input_7
# 1 conv2d_1218
# 2 batch_normalization_1218
# 3 activation_1218
# 4 conv2d_1219
# 5 batch_normalization_1219
# 6 activation_1219
# 7 conv2d_1220
# 8 batch_normalization_1220
# 9 activation_1220
# 10 max_pooling2d_24
# 11 conv2d_1221
# 12 batch_normalization_1221
# 13 activation_1221
# 14 conv2d_1222
# 15 batch_normalization_1222
# 16 activation_1222
# 17 max_pooling2d_25
# 18 conv2d_1226
# 19 batch_normalization_1226
# 20 activation_1226
# 21 conv2d_1224
# 22 conv2d_1227
# 23 batch_normalization_1224
# 24 batch_normalization_1227
# 25 activation_1224
# 26 activation_1227
# 27 average_pooling2d_6
# 28 conv2d_1223
# 29 conv2d_1225
# 30 conv2d_1228
# 31 conv2d_1229
# 32 batch_normalization_1223
# 33 batch_normalization_1225
# 34 batch_normalization_1228
# 35 batch_normalization_1229
# 36 activation_1223
# 37 activation_1225
# 38 activation_1228
# 39 activation_1229
# 40 mixed_5b
# 41 conv2d_1233
# 42 batch_normalization_1233
# 43 activation_1233
# 44 conv2d_1231
# 45 conv2d_1234
# 46 batch_normalization_1231
# 47 batch_normalization_1234
# 48 activation_1231
# 49 activation_1234
# 50 conv2d_1230
# 51 conv2d_1232
# 52 conv2d_1235
# 53 batch_normalization_1230
# 54 batch_normalization_1232
# 55 batch_normalization_1235
# 56 activation_1230
# 57 activation_1232
# 58 activation_1235
# 59 block35_1_mixed
# 60 block35_1_conv
# 61 block35_1
# 62 block35_1_ac
# 63 conv2d_1239
# 64 batch_normalization_1239
# 65 activation_1239
# 66 conv2d_1237
# 67 conv2d_1240
# 68 batch_normalization_1237
# 69 batch_normalization_1240
# 70 activation_1237
# 71 activation_1240
# 72 conv2d_1236
# 73 conv2d_1238
# 74 conv2d_1241
# 75 batch_normalization_1236
# 76 batch_normalization_1238
# 77 batch_normalization_1241
# 78 activation_1236
# 79 activation_1238
# 80 activation_1241
# 81 block35_2_mixed
# 82 block35_2_conv
# 83 block35_2
# 84 block35_2_ac
# 85 conv2d_1245
# 86 batch_normalization_1245
# 87 activation_1245
# 88 conv2d_1243
# 89 conv2d_1246
# 90 batch_normalization_1243
# 91 batch_normalization_1246
# 92 activation_1243
# 93 activation_1246
# 94 conv2d_1242
# 95 conv2d_1244
# 96 conv2d_1247
# 97 batch_normalization_1242
# 98 batch_normalization_1244
# 99 batch_normalization_1247
# 100 activation_1242
# 101 activation_1244
# 102 activation_1247
# 103 block35_3_mixed
# 104 block35_3_conv
# 105 block35_3
# 106 block35_3_ac
# 107 conv2d_1251
# 108 batch_normalization_1251
# 109 activation_1251
# 110 conv2d_1249
# 111 conv2d_1252
# 112 batch_normalization_1249
# 113 batch_normalization_1252
# 114 activation_1249
# 115 activation_1252
# 116 conv2d_1248
# 117 conv2d_1250
# 118 conv2d_1253
# 119 batch_normalization_1248
# 120 batch_normalization_1250
# 121 batch_normalization_1253
# 122 activation_1248
# 123 activation_1250
# 124 activation_1253
# 125 block35_4_mixed
# 126 block35_4_conv
# 127 block35_4
# 128 block35_4_ac
# 129 conv2d_1257
# 130 batch_normalization_1257
# 131 activation_1257
# 132 conv2d_1255
# 133 conv2d_1258
# 134 batch_normalization_1255
# 135 batch_normalization_1258
# 136 activation_1255
# 137 activation_1258
# 138 conv2d_1254
# 139 conv2d_1256
# 140 conv2d_1259
# 141 batch_normalization_1254
# 142 batch_normalization_1256
# 143 batch_normalization_1259
# 144 activation_1254
# 145 activation_1256
# 146 activation_1259
# 147 block35_5_mixed
# 148 block35_5_conv
# 149 block35_5
# 150 block35_5_ac
# 151 conv2d_1263
# 152 batch_normalization_1263
# 153 activation_1263
# 154 conv2d_1261
# 155 conv2d_1264
# 156 batch_normalization_1261
# 157 batch_normalization_1264
# 158 activation_1261
# 159 activation_1264
# 160 conv2d_1260
# 161 conv2d_1262
# 162 conv2d_1265
# 163 batch_normalization_1260
# 164 batch_normalization_1262
# 165 batch_normalization_1265
# 166 activation_1260
# 167 activation_1262
# 168 activation_1265
# 169 block35_6_mixed
# 170 block35_6_conv
# 171 block35_6
# 172 block35_6_ac
# 173 conv2d_1269
# 174 batch_normalization_1269
# 175 activation_1269
# 176 conv2d_1267
# 177 conv2d_1270
# 178 batch_normalization_1267
# 179 batch_normalization_1270
# 180 activation_1267
# 181 activation_1270
# 182 conv2d_1266
# 183 conv2d_1268
# 184 conv2d_1271
# 185 batch_normalization_1266
# 186 batch_normalization_1268
# 187 batch_normalization_1271
# 188 activation_1266
# 189 activation_1268
# 190 activation_1271
# 191 block35_7_mixed
# 192 block35_7_conv
# 193 block35_7
# 194 block35_7_ac
# 195 conv2d_1275
# 196 batch_normalization_1275
# 197 activation_1275
# 198 conv2d_1273
# 199 conv2d_1276
# 200 batch_normalization_1273
# 201 batch_normalization_1276
# 202 activation_1273
# 203 activation_1276
# 204 conv2d_1272
# 205 conv2d_1274
# 206 conv2d_1277
# 207 batch_normalization_1272
# 208 batch_normalization_1274
# 209 batch_normalization_1277
# 210 activation_1272
# 211 activation_1274
# 212 activation_1277
# 213 block35_8_mixed
# 214 block35_8_conv
# 215 block35_8
# 216 block35_8_ac
# 217 conv2d_1281
# 218 batch_normalization_1281
# 219 activation_1281
# 220 conv2d_1279
# 221 conv2d_1282
# 222 batch_normalization_1279
# 223 batch_normalization_1282
# 224 activation_1279
# 225 activation_1282
# 226 conv2d_1278
# 227 conv2d_1280
# 228 conv2d_1283
# 229 batch_normalization_1278
# 230 batch_normalization_1280
# 231 batch_normalization_1283
# 232 activation_1278
# 233 activation_1280
# 234 activation_1283
# 235 block35_9_mixed
# 236 block35_9_conv
# 237 block35_9
# 238 block35_9_ac
# 239 conv2d_1287
# 240 batch_normalization_1287
# 241 activation_1287
# 242 conv2d_1285
# 243 conv2d_1288
# 244 batch_normalization_1285
# 245 batch_normalization_1288
# 246 activation_1285
# 247 activation_1288
# 248 conv2d_1284
# 249 conv2d_1286
# 250 conv2d_1289
# 251 batch_normalization_1284
# 252 batch_normalization_1286
# 253 batch_normalization_1289
# 254 activation_1284
# 255 activation_1286
# 256 activation_1289
# 257 block35_10_mixed
# 258 block35_10_conv
# 259 block35_10
# 260 block35_10_ac
# 261 conv2d_1291
# 262 batch_normalization_1291
# 263 activation_1291
# 264 conv2d_1292
# 265 batch_normalization_1292
# 266 activation_1292
# 267 conv2d_1290
# 268 conv2d_1293
# 269 batch_normalization_1290
# 270 batch_normalization_1293
# 271 activation_1290
# 272 activation_1293
# 273 max_pooling2d_26
# 274 mixed_6a
# 275 conv2d_1295
# 276 batch_normalization_1295
# 277 activation_1295
# 278 conv2d_1296
# 279 batch_normalization_1296
# 280 activation_1296
# 281 conv2d_1294
# 282 conv2d_1297
# 283 batch_normalization_1294
# 284 batch_normalization_1297
# 285 activation_1294
# 286 activation_1297
# 287 block17_1_mixed
# 288 block17_1_conv
# 289 block17_1
# 290 block17_1_ac
# 291 conv2d_1299
# 292 batch_normalization_1299
# 293 activation_1299
# 294 conv2d_1300
# 295 batch_normalization_1300
# 296 activation_1300
# 297 conv2d_1298
# 298 conv2d_1301
# 299 batch_normalization_1298
# 300 batch_normalization_1301
# 301 activation_1298
# 302 activation_1301
# 303 block17_2_mixed
# 304 block17_2_conv
# 305 block17_2
# 306 block17_2_ac
# 307 conv2d_1303
# 308 batch_normalization_1303
# 309 activation_1303
# 310 conv2d_1304
# 311 batch_normalization_1304
# 312 activation_1304
# 313 conv2d_1302
# 314 conv2d_1305
# 315 batch_normalization_1302
# 316 batch_normalization_1305
# 317 activation_1302
# 318 activation_1305
# 319 block17_3_mixed
# 320 block17_3_conv
# 321 block17_3
# 322 block17_3_ac
# 323 conv2d_1307
# 324 batch_normalization_1307
# 325 activation_1307
# 326 conv2d_1308
# 327 batch_normalization_1308
# 328 activation_1308
# 329 conv2d_1306
# 330 conv2d_1309
# 331 batch_normalization_1306
# 332 batch_normalization_1309
# 333 activation_1306
# 334 activation_1309
# 335 block17_4_mixed
# 336 block17_4_conv
# 337 block17_4
# 338 block17_4_ac
# 339 conv2d_1311
# 340 batch_normalization_1311
# 341 activation_1311
# 342 conv2d_1312
# 343 batch_normalization_1312
# 344 activation_1312
# 345 conv2d_1310
# 346 conv2d_1313
# 347 batch_normalization_1310
# 348 batch_normalization_1313
# 349 activation_1310
# 350 activation_1313
# 351 block17_5_mixed
# 352 block17_5_conv
# 353 block17_5
# 354 block17_5_ac
# 355 conv2d_1315
# 356 batch_normalization_1315
# 357 activation_1315
# 358 conv2d_1316
# 359 batch_normalization_1316
# 360 activation_1316
# 361 conv2d_1314
# 362 conv2d_1317
# 363 batch_normalization_1314
# 364 batch_normalization_1317
# 365 activation_1314
# 366 activation_1317
# 367 block17_6_mixed
# 368 block17_6_conv
# 369 block17_6
# 370 block17_6_ac
# 371 conv2d_1319
# 372 batch_normalization_1319
# 373 activation_1319
# 374 conv2d_1320
# 375 batch_normalization_1320
# 376 activation_1320
# 377 conv2d_1318
# 378 conv2d_1321
# 379 batch_normalization_1318
# 380 batch_normalization_1321
# 381 activation_1318
# 382 activation_1321
# 383 block17_7_mixed
# 384 block17_7_conv
# 385 block17_7
# 386 block17_7_ac
# 387 conv2d_1323
# 388 batch_normalization_1323
# 389 activation_1323
# 390 conv2d_1324
# 391 batch_normalization_1324
# 392 activation_1324
# 393 conv2d_1322
# 394 conv2d_1325
# 395 batch_normalization_1322
# 396 batch_normalization_1325
# 397 activation_1322
# 398 activation_1325
# 399 block17_8_mixed
# 400 block17_8_conv
# 401 block17_8
# 402 block17_8_ac
# 403 conv2d_1327
# 404 batch_normalization_1327
# 405 activation_1327
# 406 conv2d_1328
# 407 batch_normalization_1328
# 408 activation_1328
# 409 conv2d_1326
# 410 conv2d_1329
# 411 batch_normalization_1326
# 412 batch_normalization_1329
# 413 activation_1326
# 414 activation_1329
# 415 block17_9_mixed
# 416 block17_9_conv
# 417 block17_9
# 418 block17_9_ac
# 419 conv2d_1331
# 420 batch_normalization_1331
# 421 activation_1331
# 422 conv2d_1332
# 423 batch_normalization_1332
# 424 activation_1332
# 425 conv2d_1330
# 426 conv2d_1333
# 427 batch_normalization_1330
# 428 batch_normalization_1333
# 429 activation_1330
# 430 activation_1333
# 431 block17_10_mixed
# 432 block17_10_conv
# 433 block17_10
# 434 block17_10_ac
# 435 conv2d_1335
# 436 batch_normalization_1335
# 437 activation_1335
# 438 conv2d_1336
# 439 batch_normalization_1336
# 440 activation_1336
# 441 conv2d_1334
# 442 conv2d_1337
# 443 batch_normalization_1334
# 444 batch_normalization_1337
# 445 activation_1334
# 446 activation_1337
# 447 block17_11_mixed
# 448 block17_11_conv
# 449 block17_11
# 450 block17_11_ac
# 451 conv2d_1339
# 452 batch_normalization_1339
# 453 activation_1339
# 454 conv2d_1340
# 455 batch_normalization_1340
# 456 activation_1340
# 457 conv2d_1338
# 458 conv2d_1341
# 459 batch_normalization_1338
# 460 batch_normalization_1341
# 461 activation_1338
# 462 activation_1341
# 463 block17_12_mixed
# 464 block17_12_conv
# 465 block17_12
# 466 block17_12_ac
# 467 conv2d_1343
# 468 batch_normalization_1343
# 469 activation_1343
# 470 conv2d_1344
# 471 batch_normalization_1344
# 472 activation_1344
# 473 conv2d_1342
# 474 conv2d_1345
# 475 batch_normalization_1342
# 476 batch_normalization_1345
# 477 activation_1342
# 478 activation_1345
# 479 block17_13_mixed
# 480 block17_13_conv
# 481 block17_13
# 482 block17_13_ac
# 483 conv2d_1347
# 484 batch_normalization_1347
# 485 activation_1347
# 486 conv2d_1348
# 487 batch_normalization_1348
# 488 activation_1348
# 489 conv2d_1346
# 490 conv2d_1349
# 491 batch_normalization_1346
# 492 batch_normalization_1349
# 493 activation_1346
# 494 activation_1349
# 495 block17_14_mixed
# 496 block17_14_conv
# 497 block17_14
# 498 block17_14_ac
# 499 conv2d_1351
# 500 batch_normalization_1351
# 501 activation_1351
# 502 conv2d_1352
# 503 batch_normalization_1352
# 504 activation_1352
# 505 conv2d_1350
# 506 conv2d_1353
# 507 batch_normalization_1350
# 508 batch_normalization_1353
# 509 activation_1350
# 510 activation_1353
# 511 block17_15_mixed
# 512 block17_15_conv
# 513 block17_15
# 514 block17_15_ac
# 515 conv2d_1355
# 516 batch_normalization_1355
# 517 activation_1355
# 518 conv2d_1356
# 519 batch_normalization_1356
# 520 activation_1356
# 521 conv2d_1354
# 522 conv2d_1357
# 523 batch_normalization_1354
# 524 batch_normalization_1357
# 525 activation_1354
# 526 activation_1357
# 527 block17_16_mixed
# 528 block17_16_conv
# 529 block17_16
# 530 block17_16_ac
# 531 conv2d_1359
# 532 batch_normalization_1359
# 533 activation_1359
# 534 conv2d_1360
# 535 batch_normalization_1360
# 536 activation_1360
# 537 conv2d_1358
# 538 conv2d_1361
# 539 batch_normalization_1358
# 540 batch_normalization_1361
# 541 activation_1358
# 542 activation_1361
# 543 block17_17_mixed
# 544 block17_17_conv
# 545 block17_17
# 546 block17_17_ac
# 547 conv2d_1363
# 548 batch_normalization_1363
# 549 activation_1363
# 550 conv2d_1364
# 551 batch_normalization_1364
# 552 activation_1364
# 553 conv2d_1362
# 554 conv2d_1365
# 555 batch_normalization_1362
# 556 batch_normalization_1365
# 557 activation_1362
# 558 activation_1365
# 559 block17_18_mixed
# 560 block17_18_conv
# 561 block17_18
# 562 block17_18_ac
# 563 conv2d_1367
# 564 batch_normalization_1367
# 565 activation_1367
# 566 conv2d_1368
# 567 batch_normalization_1368
# 568 activation_1368
# 569 conv2d_1366
# 570 conv2d_1369
# 571 batch_normalization_1366
# 572 batch_normalization_1369
# 573 activation_1366
# 574 activation_1369
# 575 block17_19_mixed
# 576 block17_19_conv
# 577 block17_19
# 578 block17_19_ac
# 579 conv2d_1371
# 580 batch_normalization_1371
# 581 activation_1371
# 582 conv2d_1372
# 583 batch_normalization_1372
# 584 activation_1372
# 585 conv2d_1370
# 586 conv2d_1373
# 587 batch_normalization_1370
# 588 batch_normalization_1373
# 589 activation_1370
# 590 activation_1373
# 591 block17_20_mixed
# 592 block17_20_conv
# 593 block17_20
# 594 block17_20_ac
# 595 conv2d_1378
# 596 batch_normalization_1378
# 597 activation_1378
# 598 conv2d_1374
# 599 conv2d_1376
# 600 conv2d_1379
# 601 batch_normalization_1374
# 602 batch_normalization_1376
# 603 batch_normalization_1379
# 604 activation_1374
# 605 activation_1376
# 606 activation_1379
# 607 conv2d_1375
# 608 conv2d_1377
# 609 conv2d_1380
# 610 batch_normalization_1375
# 611 batch_normalization_1377
# 612 batch_normalization_1380
# 613 activation_1375
# 614 activation_1377
# 615 activation_1380
# 616 max_pooling2d_27
# 617 mixed_7a
# 618 conv2d_1382
# 619 batch_normalization_1382
# 620 activation_1382
# 621 conv2d_1383
# 622 batch_normalization_1383
# 623 activation_1383
# 624 conv2d_1381
# 625 conv2d_1384
# 626 batch_normalization_1381
# 627 batch_normalization_1384
# 628 activation_1381
# 629 activation_1384
# 630 block8_1_mixed
# 631 block8_1_conv
# 632 block8_1
# 633 block8_1_ac
# 634 conv2d_1386
# 635 batch_normalization_1386
# 636 activation_1386
# 637 conv2d_1387
# 638 batch_normalization_1387
# 639 activation_1387
# 640 conv2d_1385
# 641 conv2d_1388
# 642 batch_normalization_1385
# 643 batch_normalization_1388
# 644 activation_1385
# 645 activation_1388
# 646 block8_2_mixed
# 647 block8_2_conv
# 648 block8_2
# 649 block8_2_ac
# 650 conv2d_1390
# 651 batch_normalization_1390
# 652 activation_1390
# 653 conv2d_1391
# 654 batch_normalization_1391
# 655 activation_1391
# 656 conv2d_1389
# 657 conv2d_1392
# 658 batch_normalization_1389
# 659 batch_normalization_1392
# 660 activation_1389
# 661 activation_1392
# 662 block8_3_mixed
# 663 block8_3_conv
# 664 block8_3
# 665 block8_3_ac
# 666 conv2d_1394
# 667 batch_normalization_1394
# 668 activation_1394
# 669 conv2d_1395
# 670 batch_normalization_1395
# 671 activation_1395
# 672 conv2d_1393
# 673 conv2d_1396
# 674 batch_normalization_1393
# 675 batch_normalization_1396
# 676 activation_1393
# 677 activation_1396
# 678 block8_4_mixed
# 679 block8_4_conv
# 680 block8_4
# 681 block8_4_ac
# 682 conv2d_1398
# 683 batch_normalization_1398
# 684 activation_1398
# 685 conv2d_1399
# 686 batch_normalization_1399
# 687 activation_1399
# 688 conv2d_1397
# 689 conv2d_1400
# 690 batch_normalization_1397
# 691 batch_normalization_1400
# 692 activation_1397
# 693 activation_1400
# 694 block8_5_mixed
# 695 block8_5_conv
# 696 block8_5
# 697 block8_5_ac
# 698 conv2d_1402
# 699 batch_normalization_1402
# 700 activation_1402
# 701 conv2d_1403
# 702 batch_normalization_1403
# 703 activation_1403
# 704 conv2d_1401
# 705 conv2d_1404
# 706 batch_normalization_1401
# 707 batch_normalization_1404
# 708 activation_1401
# 709 activation_1404
# 710 block8_6_mixed
# 711 block8_6_conv
# 712 block8_6
# 713 block8_6_ac
# 714 conv2d_1406
# 715 batch_normalization_1406
# 716 activation_1406
# 717 conv2d_1407
# 718 batch_normalization_1407
# 719 activation_1407
# 720 conv2d_1405
# 721 conv2d_1408
# 722 batch_normalization_1405
# 723 batch_normalization_1408
# 724 activation_1405
# 725 activation_1408
# 726 block8_7_mixed
# 727 block8_7_conv
# 728 block8_7
# 729 block8_7_ac
# 730 conv2d_1410
# 731 batch_normalization_1410
# 732 activation_1410
# 733 conv2d_1411
# 734 batch_normalization_1411
# 735 activation_1411
# 736 conv2d_1409
# 737 conv2d_1412
# 738 batch_normalization_1409
# 739 batch_normalization_1412
# 740 activation_1409
# 741 activation_1412
# 742 block8_8_mixed
# 743 block8_8_conv
# 744 block8_8
# 745 block8_8_ac
# 746 conv2d_1414
# 747 batch_normalization_1414
# 748 activation_1414
# 749 conv2d_1415
# 750 batch_normalization_1415
# 751 activation_1415
# 752 conv2d_1413
# 753 conv2d_1416
# 754 batch_normalization_1413
# 755 batch_normalization_1416
# 756 activation_1413
# 757 activation_1416
# 758 block8_9_mixed
# 759 block8_9_conv
# 760 block8_9
# 761 block8_9_ac
# 762 conv2d_1418
# 763 batch_normalization_1418
# 764 activation_1418
# 765 conv2d_1419
# 766 batch_normalization_1419
# 767 activation_1419
# 768 conv2d_1417
# 769 conv2d_1420
# 770 batch_normalization_1417
# 771 batch_normalization_1420
# 772 activation_1417
# 773 activation_1420
# 774 block8_10_mixed
# 775 block8_10_conv
# 776 block8_10
# 777 conv_7b
# 778 conv_7b_bn
# 779 conv_7b_ac
# 780 global_max_pooling2d_6
# 781 dense_30
# 782 dropout_24
# 783 dense_31
# 784 dropout_25
# 785 dense_32
# 786 dropout_26
# 787 dense_33
# 788 dropout_27
# 789 dense_34

# %%
# set layers for training
#layer upto 790 is already trained

for layer in efficent_model.layers[:790]:
  layer.trainable=False
for layer in efficent_model.layers[790:]:
  layer.trainable=True

# %%
# prepare Training data
train_generator=ImageDataGenerator()
#train_generator=ImageDataGenerator(preprocessing_function=tf.keras.applications.efficientnet_v2.preprocess_input)
train_data=train_generator.flow_from_directory("/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/training",target_size=(150,150),class_mode='categorical', shuffle=True)
# Out:
# Found 1080 images belonging to 2 classes.

# %%
# prepare Validation data
valid_generator=ImageDataGenerator()
valid_data=valid_generator.flow_from_directory("/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/validation",target_size=(150,150),class_mode='categorical',shuffle=True)
# Out:
# Found 422 images belonging to 2 classes.

# %%
# prepare Test data
test_generator=ImageDataGenerator()
test_data=test_generator.flow_from_directory("/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/test",target_size=(224,224),class_mode='categorical',shuffle=True)
# Out:
# Found 292 images belonging to 2 classes.

# %%
train_data.class_indices
# Out:
# {'caries': 0, 'no-caries': 1}

# %%
valid_data.class_indices
# Out:
# {'caries': 0, 'no-caries': 1}

# %%
test_data.class_indices
# Out:
# {'caries': 0, 'no-caries': 1}

# %%
hist=efficent_model.fit(train_data, epochs=60,validation_data=valid_data)
# Out:
# Epoch 1/60
# 34/34 [==============================] - 35s 487ms/step - loss: 0.6476 - accuracy: 0.6750 - val_loss: 0.7597 - val_accuracy: 0.4929
# Epoch 2/60
# 34/34 [==============================] - 10s 279ms/step - loss: 0.4113 - accuracy: 0.8019 - val_loss: 0.6665 - val_accuracy: 0.5000
# Epoch 3/60
# 34/34 [==============================] - 10s 296ms/step - loss: 0.1749 - accuracy: 0.9306 - val_loss: 0.4531 - val_accuracy: 0.7915
# Epoch 4/60
# 34/34 [==============================] - 10s 301ms/step - loss: 0.0687 - accuracy: 0.9759 - val_loss: 0.3204 - val_accuracy: 0.9028
# Epoch 5/60
# 34/34 [==============================] - 10s 305ms/step - loss: 0.0408 - accuracy: 0.9889 - val_loss: 0.2135 - val_accuracy: 0.9479
# Epoch 6/60
# 34/34 [==============================] - 10s 288ms/step - loss: 0.0281 - accuracy: 0.9898 - val_loss: 0.1483 - val_accuracy: 0.9526
# Epoch 7/60
# 34/34 [==============================] - 10s 297ms/step - loss: 0.0094 - accuracy: 0.9981 - val_loss: 0.1292 - val_accuracy: 0.9431
# Epoch 8/60
# 34/34 [==============================] - 10s 303ms/step - loss: 0.0111 - accuracy: 0.9972 - val_loss: 0.1547 - val_accuracy: 0.9313
# Epoch 9/60
# 34/34 [==============================] - 10s 307ms/step - loss: 0.0126 - accuracy: 0.9963 - val_loss: 0.1707 - val_accuracy: 0.9479
# Epoch 10/60
# 34/34 [==============================] - 11s 325ms/step - loss: 0.0198 - accuracy: 0.9926 - val_loss: 0.0748 - val_accuracy: 0.9763
# Epoch 11/60
# 34/34 [==============================] - 11s 311ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0291 - val_accuracy: 0.9882
# Epoch 12/60
# 34/34 [==============================] - 12s 348ms/step - loss: 0.0074 - accuracy: 0.9972 - val_loss: 0.0801 - val_accuracy: 0.9716
# Epoch 13/60
# 34/34 [==============================] - 10s 305ms/step - loss: 0.0054 - accuracy: 0.9981 - val_loss: 0.1276 - val_accuracy: 0.9597
# Epoch 14/60
# 34/34 [==============================] - 11s 325ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1595 - val_accuracy: 0.9573
# Epoch 15/60
# 34/34 [==============================] - 11s 313ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1555 - val_accuracy: 0.9597
# Epoch 16/60
# 34/34 [==============================] - 10s 306ms/step - loss: 0.0032 - accuracy: 0.9981 - val_loss: 0.0699 - val_accuracy: 0.9787
# Epoch 17/60
# 34/34 [==============================] - 11s 333ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.4489 - val_accuracy: 0.8199
# Epoch 18/60
# 34/34 [==============================] - 11s 326ms/step - loss: 0.0040 - accuracy: 0.9991 - val_loss: 0.0740 - val_accuracy: 0.9787
# Epoch 19/60
# 34/34 [==============================] - 10s 295ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.0733 - val_accuracy: 0.9763
# Epoch 20/60
# 34/34 [==============================] - 11s 310ms/step - loss: 0.0067 - accuracy: 0.9981 - val_loss: 0.3770 - val_accuracy: 0.8555
# Epoch 21/60
# 34/34 [==============================] - 11s 314ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0792 - val_accuracy: 0.9810
# Epoch 22/60
# 34/34 [==============================] - 11s 316ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0752 - val_accuracy: 0.9810
# Epoch 23/60
# 34/34 [==============================] - 10s 294ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1179 - val_accuracy: 0.9716
# Epoch 24/60
# 34/34 [==============================] - 11s 310ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9692
# Epoch 25/60
# 34/34 [==============================] - 11s 311ms/step - loss: 4.3719e-04 - accuracy: 1.0000 - val_loss: 0.1128 - val_accuracy: 0.9739
# Epoch 26/60
# 34/34 [==============================] - 11s 311ms/step - loss: 8.7997e-04 - accuracy: 1.0000 - val_loss: 0.0843 - val_accuracy: 0.9834
# Epoch 27/60
# 34/34 [==============================] - 11s 310ms/step - loss: 0.0025 - accuracy: 0.9991 - val_loss: 0.0647 - val_accuracy: 0.9858
# Epoch 28/60
# 34/34 [==============================] - 10s 297ms/step - loss: 3.7459e-04 - accuracy: 1.0000 - val_loss: 0.0587 - val_accuracy: 0.9882
# Epoch 29/60
# 34/34 [==============================] - 11s 316ms/step - loss: 7.4359e-04 - accuracy: 1.0000 - val_loss: 0.0579 - val_accuracy: 0.9858
# Epoch 30/60
# 34/34 [==============================] - 11s 313ms/step - loss: 3.8844e-04 - accuracy: 1.0000 - val_loss: 0.0646 - val_accuracy: 0.9858
# Epoch 31/60
# 34/34 [==============================] - 11s 338ms/step - loss: 3.9686e-04 - accuracy: 1.0000 - val_loss: 0.0646 - val_accuracy: 0.9858
# Epoch 32/60
# 34/34 [==============================] - 11s 331ms/step - loss: 4.2950e-04 - accuracy: 1.0000 - val_loss: 0.0584 - val_accuracy: 0.9858
# Epoch 33/60
# 34/34 [==============================] - 10s 297ms/step - loss: 6.2894e-04 - accuracy: 1.0000 - val_loss: 0.0354 - val_accuracy: 0.9905
# Epoch 34/60
# 34/34 [==============================] - 11s 315ms/step - loss: 0.0047 - accuracy: 0.9991 - val_loss: 0.4838 - val_accuracy: 0.9100
# Epoch 35/60
# 34/34 [==============================] - 11s 308ms/step - loss: 0.0021 - accuracy: 0.9981 - val_loss: 0.1839 - val_accuracy: 0.9597
# Epoch 36/60
# 34/34 [==============================] - 11s 317ms/step - loss: 5.6023e-04 - accuracy: 1.0000 - val_loss: 0.1292 - val_accuracy: 0.9716
# Epoch 37/60
# 34/34 [==============================] - 11s 309ms/step - loss: 5.6402e-04 - accuracy: 1.0000 - val_loss: 0.1095 - val_accuracy: 0.9763
# Epoch 38/60
# 34/34 [==============================] - 11s 310ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1034 - val_accuracy: 0.9763
# Epoch 39/60
# 34/34 [==============================] - 11s 311ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1089 - val_accuracy: 0.9787
# Epoch 40/60
# 34/34 [==============================] - 11s 310ms/step - loss: 6.7075e-04 - accuracy: 1.0000 - val_loss: 0.1235 - val_accuracy: 0.9692
# Epoch 41/60
# 34/34 [==============================] - 11s 312ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0848 - val_accuracy: 0.9858
# Epoch 42/60
# 34/34 [==============================] - 10s 306ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1780 - val_accuracy: 0.9645
# Epoch 43/60
# 34/34 [==============================] - 11s 333ms/step - loss: 0.0039 - accuracy: 0.9981 - val_loss: 0.0588 - val_accuracy: 0.9787
# Epoch 44/60
# 34/34 [==============================] - 11s 329ms/step - loss: 0.0025 - accuracy: 0.9991 - val_loss: 0.1682 - val_accuracy: 0.9597
# Epoch 45/60
# 34/34 [==============================] - 10s 299ms/step - loss: 0.0018 - accuracy: 0.9991 - val_loss: 0.0669 - val_accuracy: 0.9858
# Epoch 46/60
# 34/34 [==============================] - 11s 318ms/step - loss: 0.0123 - accuracy: 0.9963 - val_loss: 0.1851 - val_accuracy: 0.9621
# Epoch 47/60
# 34/34 [==============================] - 11s 313ms/step - loss: 0.0024 - accuracy: 0.9991 - val_loss: 0.1445 - val_accuracy: 0.9692
# Epoch 48/60
# 34/34 [==============================] - 11s 318ms/step - loss: 0.0071 - accuracy: 0.9972 - val_loss: 0.2069 - val_accuracy: 0.9455
# Epoch 49/60
# 34/34 [==============================] - 11s 331ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2856 - val_accuracy: 0.9313
# Epoch 50/60
# 34/34 [==============================] - 10s 299ms/step - loss: 8.3482e-04 - accuracy: 1.0000 - val_loss: 0.0938 - val_accuracy: 0.9787
# Epoch 51/60
# 34/34 [==============================] - 11s 315ms/step - loss: 7.4449e-04 - accuracy: 1.0000 - val_loss: 0.0741 - val_accuracy: 0.9810
# Epoch 52/60
# 34/34 [==============================] - 11s 317ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0655 - val_accuracy: 0.9810
# Epoch 53/60
# 34/34 [==============================] - 11s 314ms/step - loss: 3.3079e-04 - accuracy: 1.0000 - val_loss: 0.0456 - val_accuracy: 0.9834
# Epoch 54/60
# 34/34 [==============================] - 11s 331ms/step - loss: 3.3088e-04 - accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9834
# Epoch 55/60
# 34/34 [==============================] - 11s 313ms/step - loss: 3.0530e-04 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9882
# Epoch 56/60
# 34/34 [==============================] - 10s 305ms/step - loss: 2.7946e-04 - accuracy: 1.0000 - val_loss: 0.0375 - val_accuracy: 0.9905
# Epoch 57/60
# 34/34 [==============================] - 11s 333ms/step - loss: 1.6620e-04 - accuracy: 1.0000 - val_loss: 0.0389 - val_accuracy: 0.9882
# Epoch 58/60
# 34/34 [==============================] - 10s 294ms/step - loss: 1.1360e-04 - accuracy: 1.0000 - val_loss: 0.0385 - val_accuracy: 0.9905
# Epoch 59/60
# 34/34 [==============================] - 11s 307ms/step - loss: 2.6557e-04 - accuracy: 1.0000 - val_loss: 0.0433 - val_accuracy: 0.9858
# Epoch 60/60
# 34/34 [==============================] - 11s 310ms/step - loss: 1.9266e-04 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.9882

# %%
final_model=efficent_model.save("Inception.h5")

# %% [markdown]
# # **Part - 4**

# %%
plt.plot(hist.history['loss'], label='Training loss')
plt.plot(hist.history['val_loss'], label='Test loss')
plt.xlabel("Epoches")
plt.ylabel("Training loss")
plt.title("Training v/s Test Loss Progress")
plt.legend()

# %%
plt.plot(hist.history['accuracy'], label='Training Accuracy')
plt.plot(hist.history['val_accuracy'], label='Test Accuracy')
plt.xlabel("Epoches")
plt.ylabel("Training Accuracy")
plt.title("Training v/s Test Accuracy progress")
plt.legend()

# %% [markdown]
# # **Part - 5**

# %% [markdown]
# Training Data

# %%
# prepare Training data
train_generator=ImageDataGenerator()
#train_generator=ImageDataGenerator(preprocessing_function=tf.keras.applications.efficientnet_v2.preprocess_input)
train_data_1 = train_generator.flow_from_directory("/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/training",target_size=(150,150),class_mode='categorical',batch_size=32, shuffle=False)
# Out:
# Found 1080 images belonging to 2 classes.

# %%
train_data_1.classes
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int32)

# %%
# Training Data
actual_train_class=train_data_1.classes
actual_valid_class=valid_data.classes
from sklearn.metrics import confusion_matrix
train_data_1.reset()
y_train_pred = efficent_model.predict(train_data_1)
y_train_pred =np.argmax(y_train_pred, axis=1)
# Out:
# 34/34 [==============================] - 7s 97ms/step

# %%
cm = confusion_matrix(actual_train_class, y_train_pred)
sns.heatmap(cm, annot=True,fmt='d', xticklabels=['Caries','No Caries'], yticklabels=['Caries','No Caries'],cbar=False)

from sklearn.metrics import accuracy_score, classification_report
accuracy_score(actual_train_class, y_train_pred)
# Out:
# 1.0

# %%
print(classification_report(actual_train_class, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       765
#            1       1.00      1.00      1.00       315
#
#     accuracy                           1.00      1080
#    macro avg       1.00      1.00      1.00      1080
# weighted avg       1.00      1.00      1.00      1080

# %%
print(efficent_model.evaluate(train_data_1))
# Out:
# 34/34 [==============================] - 4s 102ms/step - loss: 2.1696e-06 - accuracy: 1.0000
# [2.169618937841733e-06, 1.0]

# %% [markdown]
# Validation Data

# %%
# prepare Validation data
valid_generator=ImageDataGenerator()
valid_data_1 = valid_generator.flow_from_directory("/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/validation",target_size=(150,150),class_mode='categorical',shuffle=False,batch_size=32)
# Out:
# Found 422 images belonging to 2 classes.

# %%
actual_valid_class=valid_data_1.classes

y_valid_pred = efficent_model.predict(valid_data_1)
y_valid_pred =np.argmax(y_valid_pred, axis=1)

cm = confusion_matrix(actual_valid_class, y_valid_pred)
sns.heatmap(cm, annot=True,fmt='d', xticklabels=['Caries','No Caries'], yticklabels=['Caries','No Caries'],cbar=False)
# Out:
# 14/14 [==============================] - 1s 95ms/step
# <Axes: >

# %%
print(classification_report(actual_valid_class, y_valid_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       211
#            1       1.00      0.98      0.99       211
#
#     accuracy                           0.99       422
#    macro avg       0.99      0.99      0.99       422
# weighted avg       0.99      0.99      0.99       422

# %%
print(efficent_model.evaluate(valid_data_1))
# Out:
# 14/14 [==============================] - 1s 94ms/step - loss: 0.0412 - accuracy: 0.9882
# [0.041231367737054825, 0.9881516695022583]

# %% [markdown]
# Test Data

# %%
# prepare Test data
test_generator=ImageDataGenerator()
test_data_1 = test_generator.flow_from_directory("/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/test",target_size=(150,150),class_mode='categorical',shuffle=False,batch_size=32)
# Out:
# Found 292 images belonging to 2 classes.

# %%
actual_test_class=test_data_1.classes

y_test_pred = efficent_model.predict(test_data_1)
y_test_pred =np.argmax(y_test_pred, axis=1)

cm = confusion_matrix(actual_test_class, y_test_pred)
sns.heatmap(cm, annot=True,fmt='d', xticklabels=['Caries','No Caries'], yticklabels=['Caries','No Caries'],cbar=False)
# Out:
# 10/10 [==============================] - 2s 164ms/step
# <Axes: >

# %%
print(classification_report(actual_test_class, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95       210
#            1       0.96      0.79      0.87        82
#
#     accuracy                           0.93       292
#    macro avg       0.94      0.89      0.91       292
# weighted avg       0.93      0.93      0.93       292

# %%
print(efficent_model.evaluate(test_data_1))
# Out:
# 10/10 [==============================] - 1s 92ms/step - loss: 0.3451 - accuracy: 0.9315
# [0.3451484143733978, 0.931506872177124]

# %% [markdown]
# # **Part - 6**

# %% [markdown]
# Training

# %%
from tensorflow.keras.preprocessing.image import img_to_array
fig, axes=plt.subplots(2,3, figsize=(10,10))
axes=axes.ravel()
plt.subplots_adjust(hspace=0.4)

i=0
for j in train_caries_image:
  if(i<=2):
    test_img=load_img(train_caries_path+'/'+j, target_size=(150,150))
    axes[i].imshow(test_img)
    test_img=img_to_array(test_img)
    test_imag= test_img.reshape(1,150,150,3)
   
    pred=efficent_model.predict(test_imag)
    pred= np.argmax(pred)
    if pred==0:
      result='Caries'
    elif pred==1:
      result='Without Caries'

    axes[i].set_title("Actual: Caries \n Predicted: {}".format(result))
    axes[i].axis('off')
    i=i+1
    
for j in train_no_caries_image:
  if(i>2 and i <6):
    test_img=load_img(train_no_caries_path+'/'+j, target_size=(150,150))
    axes[i].imshow(test_img)
    test_img=img_to_array(test_img)
    test_imag= test_img.reshape(1,150,150,3)
  
    pred=efficent_model.predict(test_imag)
    pred= np.argmax(pred)
    if pred==0:
      result='Caries'
    elif pred==1:
      result='Without Caries'

    axes[i].set_title("Actual: Without Caries \n Predicted: {}".format(result))
    axes[i].axis('off')
    i=i+1
 

fig.tight_layout()
fig.tight_layout()
fig.tight_layout()
fig.tight_layout()
# Out:
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step

# %% [markdown]
# Validation

# %%
from tensorflow.keras.preprocessing.image import img_to_array
fig, axes=plt.subplots(2,3, figsize=(10,10))
axes=axes.ravel()
plt.subplots_adjust(hspace=0.4)

i=0
for j in valid_caries_image:
  if(i<=2):
    test_img=load_img(valid_caries_path+'/'+j, target_size=(150,150))
    axes[i].imshow(test_img)
    test_img=img_to_array(test_img)
    test_imag= test_img.reshape(1,150,150,3)
   
    pred=efficent_model.predict(test_imag)
    pred= np.argmax(pred)
    if pred==0:
      result='Caries'
    elif pred==1:
      result='Without Caries'

    axes[i].set_title("Actual: Caries \n Predicted: {}".format(result))
    axes[i].axis('off')
    i=i+1
    
for j in valid_no_caries_image:
  if(i>2 and i <6):
    test_img=load_img(valid_no_caries_path+'/'+j, target_size=(150,150))
    axes[i].imshow(test_img)
    test_img=img_to_array(test_img)
    test_imag= test_img.reshape(1,150,150,3)
  
    pred=efficent_model.predict(test_imag)
    pred= np.argmax(pred)
    if pred==0:
      result='Caries'
    elif pred==1:
      result='Without Caries'

    axes[i].set_title("Actual: Without Caries \n Predicted: {}".format(result))
    axes[i].axis('off')
    i=i+1
 

fig.tight_layout()
fig.tight_layout()
fig.tight_layout()
fig.tight_layout()
# Out:
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 76ms/step

# %% [markdown]
# Test

# %%
from tensorflow.keras.preprocessing.image import img_to_array
fig, axes=plt.subplots(2,3, figsize=(10,10))
axes=axes.ravel()
plt.subplots_adjust(hspace=0.4)

i=0
for j in test_caries_image:
  if(i<=2):
    test_img=load_img(test_caries_path+'/'+j, target_size=(150,150))
    axes[i].imshow(test_img)
    test_img=img_to_array(test_img)
    test_imag= test_img.reshape(1,150,150,3)
   
    pred=efficent_model.predict(test_imag)
    pred= np.argmax(pred)
    if pred==0:
      result='Caries'
    elif pred==1:
      result='Without Caries'

    axes[i].set_title("Actual: Caries \n Predicted: {}".format(result))
    axes[i].axis('off')
    i=i+1
    
for j in test_no_caries_image:
  if(i>2 and i <6):
    test_img=load_img(test_no_caries_path+'/'+j, target_size=(150,150))
    axes[i].imshow(test_img)
    test_img=img_to_array(test_img)
    test_imag= test_img.reshape(1,150,150,3)
  
    pred=efficent_model.predict(test_imag)
    pred= np.argmax(pred)
    if pred==0:
      result='Caries'
    elif pred==1:
      result='Without Caries'

    axes[i].set_title("Actual: Without Caries \n Predicted: {}".format(result))
    axes[i].axis('off')
    i=i+1
 

fig.tight_layout()
fig.tight_layout()
fig.tight_layout()
fig.tight_layout()
# Out:
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
