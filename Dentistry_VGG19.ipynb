# %% [markdown]
# # **Part - 1**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import tensorflow as tf
import tensorflow
from tensorflow.keras.preprocessing.image import load_img, ImageDataGenerator
import cv2
import time
import random
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Activation

# %%
# Path to Datasets
# Training Path
train_caries_path = "/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/training/caries"
train_no_caries_path = "/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/training/no-caries"

# Testing Path 
valid_caries_path = "/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/validation/caries"
valid_no_caries_path = "/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/validation/no-caries"

# Testing Path 
test_caries_path = "/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/test/caries"
test_no_caries_path = "/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/test/no-caries"

# %%
# Making Directory of Images
# Training Images
train_caries_image = os.listdir(train_caries_path)
train_no_caries_image = os.listdir(train_no_caries_path)

#Validation Images
valid_caries_image = os.listdir(valid_caries_path)
valid_no_caries_image = os.listdir(valid_no_caries_path)

#Testing Images
test_caries_image = os.listdir(test_caries_path)
test_no_caries_image = os.listdir(test_no_caries_path)

# %%
# Printing Numbers of Images in each Dataset
print("Number of Caries Images in Training = ",len(train_caries_image))
print("Number of No Caries Images in Training = ",len(train_no_caries_image))

print('\n')
print("Number of Caries Images in Validation = ",len(valid_caries_image))
print("Number of No Caries Images in Validation = ",len(valid_no_caries_image))

print('\n')
print("Number of Caries Images in Testing = ",len(test_caries_image))
print("Number of No Caries Images in Testing = ",len(test_no_caries_image))
# Out:
# Number of Caries Images in Training =  765
# Number of No Caries Images in Training =  315
#
#
# Number of Caries Images in Validation =  211
# Number of No Caries Images in Validation =  211
#
#
# Number of Caries Images in Testing =  210
# Number of No Caries Images in Testing =  82

# %% [markdown]
# # **Part - 2**

# %% [markdown]
# Training Data

# %%
m=0
fig, axes = plt.subplots(2,3, figsize=(10,10))
axes = axes.ravel()

for i in range(3):
  img = plt.imread(train_caries_path + '/' + random.choice(train_caries_image))
  axes[m].imshow(img)
  axes[m].set_title("Caries")
  m=m+1

for i in range(3):
  img = plt.imread(train_no_caries_path + '/' + random.choice(train_no_caries_image))
  axes[m].imshow(img)
  axes[m].set_title("No - Caries")
  m=m+1

# %% [markdown]
# Validation Data

# %%
m=0
fig, axes = plt.subplots(2,3, figsize=(10,10))
axes = axes.ravel()

for i in range(3):
  img = plt.imread(valid_caries_path + '/' + random.choice(valid_caries_image))
  axes[m].imshow(img)
  axes[m].set_title("Caries")
  m=m+1

for i in range(3):
  img = plt.imread(valid_no_caries_path + '/' + random.choice(valid_no_caries_image))
  axes[m].imshow(img)
  axes[m].set_title("No - Caries")
  m=m+1

# %% [markdown]
# Test Data

# %%
m=0
fig, axes = plt.subplots(2,3, figsize=(10,10))
axes = axes.ravel()

for i in range(3):
  img = plt.imread(test_caries_path + '/' + random.choice(test_caries_image))
  axes[m].imshow(img)
  axes[m].set_title("Caries")
  m=m+1

for i in range(3):
  img = plt.imread(test_no_caries_path + '/' + random.choice(test_no_caries_image))
  axes[m].imshow(img)
  axes[m].set_title("No - Caries")
  m=m+1

# %% [markdown]
# # **Part - 3**

# %% [markdown]
# Model

# %%
# Model
model=tf.keras.applications.vgg19.VGG19(weights='imagenet',include_top=False)
# Design new model
x=model.output
x=tf.keras.layers.GlobalMaxPool2D()(x)
x=tf.keras.layers.Dense(512,activation='relu')(x)
x=tf.keras.layers.Dropout(0.3)(x)
x = tf.keras.layers.Dense(512, activation = 'relu')(x)
x=tf.keras.layers.Dropout(0.3)(x)
x = tf.keras.layers.Dense(1024, activation = 'relu')(x)
x=tf.keras.layers.Dropout(0.3)(x)
x = tf.keras.layers.Dense(1024, activation = 'relu')(x)
x=tf.keras.layers.Dropout(0.3)(x)
preds = tf.keras.layers.Dense(2, activation = 'softmax')(x)  # This layer will have output. So It will have only one neuron
efficent_model=tf.keras.models.Model(inputs = model.input, outputs = preds)
opt=tf.keras.optimizers.legacy.SGD(learning_rate=0.001, decay=1e-6, momentum=0.9, nesterov=True)
efficent_model.compile(loss=tf.keras.losses.categorical_crossentropy,optimizer=opt,metrics=['accuracy'])
efficent_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 3s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv4 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  global_max_pooling2d (Globa  (None, 512)              0
#  lMaxPooling2D)
#
#  dense (Dense)               (None, 512)               262656
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 1024)              525312
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_3 (Dense)             (None, 1024)              1049600
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_4 (Dense)             (None, 2)                 2050
#
# =================================================================
# Total params: 22,126,658
# Trainable params: 22,126,658
# Non-trainable params: 0
# _________________________________________________________________

# %%
for i,layer in enumerate(efficent_model.layers):
  print(i,layer.name)
# Out:
# 0 input_1
# 1 block1_conv1
# 2 block1_conv2
# 3 block1_pool
# 4 block2_conv1
# 5 block2_conv2
# 6 block2_pool
# 7 block3_conv1
# 8 block3_conv2
# 9 block3_conv3
# 10 block3_conv4
# 11 block3_pool
# 12 block4_conv1
# 13 block4_conv2
# 14 block4_conv3
# 15 block4_conv4
# 16 block4_pool
# 17 block5_conv1
# 18 block5_conv2
# 19 block5_conv3
# 20 block5_conv4
# 21 block5_pool
# 22 global_max_pooling2d
# 23 dense
# 24 dropout
# 25 dense_1
# 26 dropout_1
# 27 dense_2
# 28 dropout_2
# 29 dense_3
# 30 dropout_3
# 31 dense_4

# %%
# set layers for training
#layer upto 32 are already trained

for layer in efficent_model.layers[:32]:
  layer.trainable=False
for layer in efficent_model.layers[32:]:
  layer.trainable=True

# %%
# prepare Training data
train_generator=ImageDataGenerator()
#train_generator=ImageDataGenerator(preprocessing_function=tf.keras.applications.efficientnet_v2.preprocess_input)
train_data=train_generator.flow_from_directory("/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/training",target_size=(150,150),class_mode='categorical', shuffle=True)
# Out:
# Found 1080 images belonging to 2 classes.

# %%
# prepare Validation data
valid_generator=ImageDataGenerator()
valid_data=valid_generator.flow_from_directory("/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/validation",target_size=(150,150),class_mode='categorical',shuffle=True)
# Out:
# Found 422 images belonging to 2 classes.

# %%
# prepare Test data
test_generator=ImageDataGenerator()
test_data=test_generator.flow_from_directory("/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/test",target_size=(224,224),class_mode='categorical',shuffle=True)
# Out:
# Found 292 images belonging to 2 classes.

# %%
train_data.class_indices
# Out:
# {'caries': 0, 'no-caries': 1}

# %%
valid_data.class_indices
# Out:
# {'caries': 0, 'no-caries': 1}

# %%
test_data.class_indices
# Out:
# {'caries': 0, 'no-caries': 1}

# %%
hist=efficent_model.fit(train_data, epochs=60,validation_data=valid_data)
# Out:
# Epoch 1/60
# 34/34 [==============================] - 362s 10s/step - loss: 0.8987 - accuracy: 0.6713 - val_loss: 0.7292 - val_accuracy: 0.5000
# Epoch 2/60
# 34/34 [==============================] - 12s 340ms/step - loss: 0.6125 - accuracy: 0.7065 - val_loss: 0.7484 - val_accuracy: 0.5000
# Epoch 3/60
# 34/34 [==============================] - 10s 299ms/step - loss: 0.5889 - accuracy: 0.7083 - val_loss: 0.6788 - val_accuracy: 0.5000
# Epoch 4/60
# 34/34 [==============================] - 10s 299ms/step - loss: 0.5771 - accuracy: 0.7083 - val_loss: 0.7141 - val_accuracy: 0.5000
# Epoch 5/60
# 34/34 [==============================] - 10s 302ms/step - loss: 0.5697 - accuracy: 0.7083 - val_loss: 0.7757 - val_accuracy: 0.5000
# Epoch 6/60
# 34/34 [==============================] - 10s 291ms/step - loss: 0.6128 - accuracy: 0.7083 - val_loss: 0.7511 - val_accuracy: 0.5000
# Epoch 7/60
# 34/34 [==============================] - 10s 301ms/step - loss: 0.5299 - accuracy: 0.7083 - val_loss: 0.6497 - val_accuracy: 0.5000
# Epoch 8/60
# 34/34 [==============================] - 11s 336ms/step - loss: 0.5765 - accuracy: 0.7083 - val_loss: 0.6964 - val_accuracy: 0.5000
# Epoch 9/60
# 34/34 [==============================] - 10s 304ms/step - loss: 0.5754 - accuracy: 0.7083 - val_loss: 0.5074 - val_accuracy: 0.5000
# Epoch 10/60
# 34/34 [==============================] - 10s 293ms/step - loss: 0.5098 - accuracy: 0.7083 - val_loss: 0.6813 - val_accuracy: 0.5000
# Epoch 11/60
# 34/34 [==============================] - 10s 289ms/step - loss: 0.6358 - accuracy: 0.7083 - val_loss: 0.7137 - val_accuracy: 0.5000
# Epoch 12/60
# 34/34 [==============================] - 11s 334ms/step - loss: 0.5593 - accuracy: 0.7083 - val_loss: 0.5543 - val_accuracy: 0.5000
# Epoch 13/60
# 34/34 [==============================] - 10s 297ms/step - loss: 0.4225 - accuracy: 0.7083 - val_loss: 0.5332 - val_accuracy: 0.5000
# Epoch 14/60
# 34/34 [==============================] - 10s 298ms/step - loss: 0.4730 - accuracy: 0.7083 - val_loss: 0.6435 - val_accuracy: 0.5000
# Epoch 15/60
# 34/34 [==============================] - 12s 339ms/step - loss: 0.4158 - accuracy: 0.7083 - val_loss: 0.4359 - val_accuracy: 0.5000
# Epoch 16/60
# 34/34 [==============================] - 14s 419ms/step - loss: 0.3777 - accuracy: 0.7083 - val_loss: 0.3939 - val_accuracy: 0.5000
# Epoch 17/60
# 34/34 [==============================] - 11s 331ms/step - loss: 0.3356 - accuracy: 0.7130 - val_loss: 0.4497 - val_accuracy: 0.8009
# Epoch 18/60
# 34/34 [==============================] - 10s 296ms/step - loss: 0.3574 - accuracy: 0.8185 - val_loss: 0.3635 - val_accuracy: 0.9645
# Epoch 19/60
# 34/34 [==============================] - 10s 304ms/step - loss: 0.3210 - accuracy: 0.8667 - val_loss: 0.3543 - val_accuracy: 0.9621
# Epoch 20/60
# 34/34 [==============================] - 11s 315ms/step - loss: 0.2928 - accuracy: 0.8935 - val_loss: 0.3292 - val_accuracy: 0.9621
# Epoch 21/60
# 34/34 [==============================] - 10s 304ms/step - loss: 0.2537 - accuracy: 0.9185 - val_loss: 0.3792 - val_accuracy: 0.8886
# Epoch 22/60
# 34/34 [==============================] - 10s 295ms/step - loss: 0.2331 - accuracy: 0.9269 - val_loss: 0.2820 - val_accuracy: 0.9882
# Epoch 23/60
# 34/34 [==============================] - 10s 303ms/step - loss: 0.3222 - accuracy: 0.8565 - val_loss: 0.3639 - val_accuracy: 0.9242
# Epoch 24/60
# 34/34 [==============================] - 11s 309ms/step - loss: 0.2676 - accuracy: 0.8880 - val_loss: 0.3885 - val_accuracy: 0.8649
# Epoch 25/60
# 34/34 [==============================] - 10s 306ms/step - loss: 0.2361 - accuracy: 0.9167 - val_loss: 0.3415 - val_accuracy: 0.9194
# Epoch 26/60
# 34/34 [==============================] - 10s 304ms/step - loss: 0.2140 - accuracy: 0.9315 - val_loss: 0.3059 - val_accuracy: 0.9384
# Epoch 27/60
# 34/34 [==============================] - 10s 301ms/step - loss: 0.1951 - accuracy: 0.9407 - val_loss: 0.2857 - val_accuracy: 0.9526
# Epoch 28/60
# 34/34 [==============================] - 11s 335ms/step - loss: 0.1810 - accuracy: 0.9444 - val_loss: 0.2870 - val_accuracy: 0.9479
# Epoch 29/60
# 34/34 [==============================] - 11s 335ms/step - loss: 0.1758 - accuracy: 0.9509 - val_loss: 0.2112 - val_accuracy: 0.9858
# Epoch 30/60
# 34/34 [==============================] - 10s 300ms/step - loss: 0.1560 - accuracy: 0.9611 - val_loss: 0.1892 - val_accuracy: 0.9953
# Epoch 31/60
# 34/34 [==============================] - 10s 301ms/step - loss: 0.1370 - accuracy: 0.9667 - val_loss: 0.1871 - val_accuracy: 0.9834
# Epoch 32/60
# 34/34 [==============================] - 10s 305ms/step - loss: 0.1400 - accuracy: 0.9685 - val_loss: 0.2228 - val_accuracy: 0.9621
# Epoch 33/60
# 34/34 [==============================] - 12s 339ms/step - loss: 0.1238 - accuracy: 0.9722 - val_loss: 0.2060 - val_accuracy: 0.9645
# Epoch 34/60
# 34/34 [==============================] - 11s 335ms/step - loss: 0.2597 - accuracy: 0.8759 - val_loss: 0.4231 - val_accuracy: 0.9194
# Epoch 35/60
# 34/34 [==============================] - 10s 298ms/step - loss: 0.2286 - accuracy: 0.9167 - val_loss: 0.3731 - val_accuracy: 0.8436
# Epoch 36/60
# 34/34 [==============================] - 10s 304ms/step - loss: 0.1523 - accuracy: 0.9509 - val_loss: 0.3010 - val_accuracy: 0.9028
# Epoch 37/60
# 34/34 [==============================] - 12s 347ms/step - loss: 0.1141 - accuracy: 0.9722 - val_loss: 0.2768 - val_accuracy: 0.9408
# Epoch 38/60
# 34/34 [==============================] - 12s 341ms/step - loss: 0.0927 - accuracy: 0.9870 - val_loss: 0.2900 - val_accuracy: 0.9384
# Epoch 39/60
# 34/34 [==============================] - 10s 301ms/step - loss: 0.0771 - accuracy: 0.9917 - val_loss: 0.2043 - val_accuracy: 0.9550
# Epoch 40/60
# 34/34 [==============================] - 10s 301ms/step - loss: 0.0717 - accuracy: 0.9935 - val_loss: 0.2099 - val_accuracy: 0.9573
# Epoch 41/60
# 34/34 [==============================] - 10s 300ms/step - loss: 0.0577 - accuracy: 0.9991 - val_loss: 0.2393 - val_accuracy: 0.9597
# Epoch 42/60
# 34/34 [==============================] - 11s 336ms/step - loss: 0.0522 - accuracy: 0.9991 - val_loss: 0.2204 - val_accuracy: 0.9739
# Epoch 43/60
# 34/34 [==============================] - 10s 306ms/step - loss: 0.0484 - accuracy: 0.9991 - val_loss: 0.2125 - val_accuracy: 0.9716
# Epoch 44/60
# 34/34 [==============================] - 10s 305ms/step - loss: 0.0449 - accuracy: 0.9991 - val_loss: 0.2063 - val_accuracy: 0.9550
# Epoch 45/60
# 34/34 [==============================] - 10s 300ms/step - loss: 0.0418 - accuracy: 0.9991 - val_loss: 0.2188 - val_accuracy: 0.9597
# Epoch 46/60
# 34/34 [==============================] - 12s 341ms/step - loss: 0.0391 - accuracy: 0.9991 - val_loss: 0.2258 - val_accuracy: 0.9716
# Epoch 47/60
# 34/34 [==============================] - 12s 342ms/step - loss: 0.0369 - accuracy: 0.9991 - val_loss: 0.2287 - val_accuracy: 0.9668
# Epoch 48/60
# 34/34 [==============================] - 10s 301ms/step - loss: 0.0363 - accuracy: 0.9981 - val_loss: 0.2390 - val_accuracy: 0.9526
# Epoch 49/60
# 34/34 [==============================] - 10s 296ms/step - loss: 0.0329 - accuracy: 0.9991 - val_loss: 0.2367 - val_accuracy: 0.9645
# Epoch 50/60
# 34/34 [==============================] - 10s 303ms/step - loss: 0.0305 - accuracy: 0.9991 - val_loss: 0.2460 - val_accuracy: 0.9668
# Epoch 51/60
# 34/34 [==============================] - 11s 312ms/step - loss: 0.0287 - accuracy: 0.9991 - val_loss: 0.2617 - val_accuracy: 0.9668
# Epoch 52/60
# 34/34 [==============================] - 10s 304ms/step - loss: 0.0274 - accuracy: 0.9991 - val_loss: 0.2662 - val_accuracy: 0.9668
# Epoch 53/60
# 34/34 [==============================] - 10s 302ms/step - loss: 0.0257 - accuracy: 0.9991 - val_loss: 0.2808 - val_accuracy: 0.9645
# Epoch 54/60
# 34/34 [==============================] - 10s 299ms/step - loss: 0.0249 - accuracy: 0.9991 - val_loss: 0.2445 - val_accuracy: 0.9645
# Epoch 55/60
# 34/34 [==============================] - 11s 334ms/step - loss: 0.0236 - accuracy: 0.9991 - val_loss: 0.2159 - val_accuracy: 0.9668
# Epoch 56/60
# 34/34 [==============================] - 11s 333ms/step - loss: 0.0225 - accuracy: 0.9991 - val_loss: 0.2311 - val_accuracy: 0.9645
# Epoch 57/60
# 34/34 [==============================] - 10s 299ms/step - loss: 0.0215 - accuracy: 0.9991 - val_loss: 0.2608 - val_accuracy: 0.9645
# Epoch 58/60
# 34/34 [==============================] - 10s 304ms/step - loss: 0.0207 - accuracy: 0.9991 - val_loss: 0.2751 - val_accuracy: 0.9645
# Epoch 59/60
# 34/34 [==============================] - 11s 319ms/step - loss: 0.0199 - accuracy: 0.9991 - val_loss: 0.1999 - val_accuracy: 0.9668
# Epoch 60/60
# 34/34 [==============================] - 10s 299ms/step - loss: 0.0190 - accuracy: 0.9991 - val_loss: 0.2128 - val_accuracy: 0.9668

# %%
final_model=efficent_model.save("vgg19.h5")

# %% [markdown]
# # **Part - 4**

# %%
plt.plot(hist.history['loss'], label='Training loss')
plt.plot(hist.history['val_loss'], label='Test loss')
plt.xlabel("Epoches")
plt.ylabel("Training loss")
plt.title("Training v/s Test Loss Progress")
plt.legend()

# %%
plt.plot(hist.history['accuracy'], label='Training Accuracy')
plt.plot(hist.history['val_accuracy'], label='Test Accuracy')
plt.xlabel("Epoches")
plt.ylabel("Training Accuracy")
plt.title("Training v/s Test Accuracy progress")
plt.legend()

# %% [markdown]
# # **Part - 5**

# %% [markdown]
# Training Data

# %%
# prepare Training data
train_generator=ImageDataGenerator()
#train_generator=ImageDataGenerator(preprocessing_function=tf.keras.applications.efficientnet_v2.preprocess_input)
train_data_1 = train_generator.flow_from_directory("/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/training",target_size=(150,150),class_mode='categorical',batch_size=32, shuffle=False)
# Out:
# Found 1080 images belonging to 2 classes.

# %%
train_data_1.classes
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int32)

# %%
# Training Data
actual_train_class=train_data_1.classes
actual_valid_class=valid_data.classes
from sklearn.metrics import confusion_matrix
train_data_1.reset()
y_train_pred = efficent_model.predict(train_data_1)
y_train_pred =np.argmax(y_train_pred, axis=1)
# Out:
# 34/34 [==============================] - 4s 95ms/step

# %%
cm = confusion_matrix(actual_train_class, y_train_pred)
sns.heatmap(cm, annot=True,fmt='d', xticklabels=['Caries','No Caries'], yticklabels=['Caries','No Caries'],cbar=False)

from sklearn.metrics import accuracy_score, classification_report
accuracy_score(actual_train_class, y_train_pred)
# Out:
# 0.9990740740740741

# %%
print(classification_report(actual_train_class, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       765
#            1       1.00      1.00      1.00       315
#
#     accuracy                           1.00      1080
#    macro avg       1.00      1.00      1.00      1080
# weighted avg       1.00      1.00      1.00      1080

# %%
print(efficent_model.evaluate(train_data_1))
# Out:
# 34/34 [==============================] - 4s 114ms/step - loss: 0.0179 - accuracy: 0.9991
# [0.017855612561106682, 0.9990741014480591]

# %% [markdown]
# Validation Data

# %%
# prepare Validation data
valid_generator=ImageDataGenerator()
valid_data_1 = valid_generator.flow_from_directory("/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/validation",target_size=(150,150),class_mode='categorical',shuffle=False,batch_size=32)
# Out:
# Found 422 images belonging to 2 classes.

# %%
actual_valid_class=valid_data_1.classes

y_valid_pred = efficent_model.predict(valid_data_1)
y_valid_pred =np.argmax(y_valid_pred, axis=1)

cm = confusion_matrix(actual_valid_class, y_valid_pred)
sns.heatmap(cm, annot=True,fmt='d', xticklabels=['Caries','No Caries'], yticklabels=['Caries','No Caries'],cbar=False)
# Out:
# 14/14 [==============================] - 2s 122ms/step
# <Axes: >

# %%
print(classification_report(actual_valid_class, y_valid_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       211
#            1       0.98      0.95      0.97       211
#
#     accuracy                           0.97       422
#    macro avg       0.97      0.97      0.97       422
# weighted avg       0.97      0.97      0.97       422

# %%
print(efficent_model.evaluate(valid_data_1))
# Out:
# 14/14 [==============================] - 1s 95ms/step - loss: 0.2128 - accuracy: 0.9668
# [0.21284672617912292, 0.9668246507644653]

# %% [markdown]
# Test Data

# %%
# prepare Test data
test_generator=ImageDataGenerator()
test_data_1 = test_generator.flow_from_directory("/content/drive/MyDrive/teeth_dataset/Augmented/teeth_dataset/test",target_size=(150,150),class_mode='categorical',shuffle=False,batch_size=32)
# Out:
# Found 292 images belonging to 2 classes.

# %%
actual_test_class=test_data_1.classes

y_test_pred = efficent_model.predict(test_data_1)
y_test_pred =np.argmax(y_test_pred, axis=1)

cm = confusion_matrix(actual_test_class, y_test_pred)
sns.heatmap(cm, annot=True,fmt='d', xticklabels=['Caries','No Caries'], yticklabels=['Caries','No Caries'],cbar=False)
# Out:
# 10/10 [==============================] - 35s 4s/step
# <Axes: >

# %%
print(classification_report(actual_test_class, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       210
#            1       0.95      0.93      0.94        82
#
#     accuracy                           0.97       292
#    macro avg       0.96      0.95      0.96       292
# weighted avg       0.97      0.97      0.97       292

# %%
print(efficent_model.evaluate(test_data_1))
# Out:
# 10/10 [==============================] - 1s 93ms/step - loss: 0.2501 - accuracy: 0.9658
# [0.25010403990745544, 0.965753436088562]

# %% [markdown]
# # **Part - 6**

# %% [markdown]
# Training

# %%
from tensorflow.keras.preprocessing.image import img_to_array
fig, axes=plt.subplots(2,3, figsize=(10,10))
axes=axes.ravel()
plt.subplots_adjust(hspace=0.4)

i=0
for j in train_caries_image:
  if(i<=2):
    test_img=load_img(train_caries_path+'/'+j, target_size=(150,150))
    axes[i].imshow(test_img)
    test_img=img_to_array(test_img)
    test_imag= test_img.reshape(1,150,150,3)
   
    pred=efficent_model.predict(test_imag)
    pred= np.argmax(pred)
    if pred==0:
      result='Caries'
    elif pred==1:
      result='Without Caries'

    axes[i].set_title("Actual: Caries \n Predicted: {}".format(result))
    axes[i].axis('off')
    i=i+1
    
for j in train_no_caries_image:
  if(i>2 and i <6):
    test_img=load_img(train_no_caries_path+'/'+j, target_size=(150,150))
    axes[i].imshow(test_img)
    test_img=img_to_array(test_img)
    test_imag= test_img.reshape(1,150,150,3)
  
    pred=efficent_model.predict(test_imag)
    pred= np.argmax(pred)
    if pred==0:
      result='Caries'
    elif pred==1:
      result='Without Caries'

    axes[i].set_title("Actual: Without Caries \n Predicted: {}".format(result))
    axes[i].axis('off')
    i=i+1
 

fig.tight_layout()
fig.tight_layout()
fig.tight_layout()
fig.tight_layout()
# Out:
# 1/1 [==============================] - 1s 766ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step

# %% [markdown]
# Validation

# %%
from tensorflow.keras.preprocessing.image import img_to_array
fig, axes=plt.subplots(2,3, figsize=(10,10))
axes=axes.ravel()
plt.subplots_adjust(hspace=0.4)

i=0
for j in valid_caries_image:
  if(i<=2):
    test_img=load_img(valid_caries_path+'/'+j, target_size=(150,150))
    axes[i].imshow(test_img)
    test_img=img_to_array(test_img)
    test_imag= test_img.reshape(1,150,150,3)
   
    pred=efficent_model.predict(test_imag)
    pred= np.argmax(pred)
    if pred==0:
      result='Caries'
    elif pred==1:
      result='Without Caries'

    axes[i].set_title("Actual: Caries \n Predicted: {}".format(result))
    axes[i].axis('off')
    i=i+1
    
for j in valid_no_caries_image:
  if(i>2 and i <6):
    test_img=load_img(valid_no_caries_path+'/'+j, target_size=(150,150))
    axes[i].imshow(test_img)
    test_img=img_to_array(test_img)
    test_imag= test_img.reshape(1,150,150,3)
  
    pred=efficent_model.predict(test_imag)
    pred= np.argmax(pred)
    if pred==0:
      result='Caries'
    elif pred==1:
      result='Without Caries'

    axes[i].set_title("Actual: Without Caries \n Predicted: {}".format(result))
    axes[i].axis('off')
    i=i+1
 

fig.tight_layout()
fig.tight_layout()
fig.tight_layout()
fig.tight_layout()
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step

# %% [markdown]
# Test

# %%
from tensorflow.keras.preprocessing.image import img_to_array
fig, axes=plt.subplots(2,3, figsize=(10,10))
axes=axes.ravel()
plt.subplots_adjust(hspace=0.4)

i=0
for j in test_caries_image:
  if(i<=2):
    test_img=load_img(test_caries_path+'/'+j, target_size=(150,150))
    axes[i].imshow(test_img)
    test_img=img_to_array(test_img)
    test_imag= test_img.reshape(1,150,150,3)
   
    pred=efficent_model.predict(test_imag)
    pred= np.argmax(pred)
    if pred==0:
      result='Caries'
    elif pred==1:
      result='Without Caries'

    axes[i].set_title("Actual: Caries \n Predicted: {}".format(result))
    axes[i].axis('off')
    i=i+1
    
for j in test_no_caries_image:
  if(i>2 and i <6):
    test_img=load_img(test_no_caries_path+'/'+j, target_size=(150,150))
    axes[i].imshow(test_img)
    test_img=img_to_array(test_img)
    test_imag= test_img.reshape(1,150,150,3)
  
    pred=efficent_model.predict(test_imag)
    pred= np.argmax(pred)
    if pred==0:
      result='Caries'
    elif pred==1:
      result='Without Caries'

    axes[i].set_title("Actual: Without Caries \n Predicted: {}".format(result))
    axes[i].axis('off')
    i=i+1
 

fig.tight_layout()
fig.tight_layout()
fig.tight_layout()
fig.tight_layout()
# Out:
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
